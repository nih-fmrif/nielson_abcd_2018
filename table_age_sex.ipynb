# %%
import pandas as pd
from pathlib import Path
from IPython.display import display

data_dir = Path('data')
long_table1 = pd.read_pickle(data_dir /'long_table.pkz')
long_table2 = pd.read_pickle(data_dir /'long_table_2.0.pkz')

# %%
gender_F = long_table2[long_table2['gender'] == 'F'].groupby('site_id_l').nunique()
female = gender_F.subjectkey
gender_F
# Out:
#            collection_id  tbl_id  dataset_id  subjectkey  src_subject_id  \
# site_id_l
# site01                 1    3284          22         148             148
# site02                 1    4681          22         214             214
# site03                 1    5205          22         239             239
# site04                 1    3838          22         174             174
# site05                 1    2842          22         127             127
# site06                 1    4739          22         217             217
# site07                 1    2557          22         114             114
# site08                 1    1648          22          73              73
# site09                 1    3516          22         159             159
# site10                 1    4090          22         185             185
# site11                 1    3142          22         141             141
# site12                 1    4726          22         217             217
# ...

# %%
gender_M = long_table2[long_table2['gender'] == 'M'].groupby('site_id_l').nunique()
display(gender_M.subjectkey)
# Out:
# site_id_l
# site01    144
# site02    236
# site03    224
# site04    167
# site05    123
# site06    209
# site07    125
# site08     67
# site09    140
# site10    181
# site11    140
# site12    221
# site13    197
# site14    229
# site15    126
# site16    467
# site17    224
# site18    118
# site19    153
# site20    243
# site21    191
# site22      7
# Name: subjectkey, dtype: int64

# %%
Months = long_table2.groupby('interview_age').nunique()
# display(Months)
Month_107 = long_table2[long_table2['interview_age'] == 107].groupby('site_id_l').nunique()
display(Month_107.subjectkey)
Month_108 = long_table2[long_table2['interview_age'] == 108].groupby('site_id_l').nunique()
Month_109 = long_table2[long_table2['interview_age'] == 109].groupby('site_id_l').nunique()
Month_110 = long_table2[long_table2['interview_age'] == 110].groupby('site_id_l').nunique()
Month_111 = long_table2[long_table2['interview_age'] == 111].groupby('site_id_l').nunique()
Month_112 = long_table2[long_table2['interview_age'] == 112].groupby('site_id_l').nunique()
Month_113 = long_table2[long_table2['interview_age'] == 113].groupby('site_id_l').nunique()
Month_114 = long_table2[long_table2['interview_age'] == 114].groupby('site_id_l').nunique()
Month_115 = long_table2[long_table2['interview_age'] == 115].groupby('site_id_l').nunique()
Month_116 = long_table2[long_table2['interview_age'] == 116].groupby('site_id_l').nunique()
Month_117 = long_table2[long_table2['interview_age'] == 117].groupby('site_id_l').nunique()
Month_118 = long_table2[long_table2['interview_age'] == 118].groupby('site_id_l').nunique()
Month_119 = long_table2[long_table2['interview_age'] == 119].groupby('site_id_l').nunique()
Month_120 = long_table2[long_table2['interview_age'] == 120].groupby('site_id_l').nunique()
Month_121 = long_table2[long_table2['interview_age'] == 121].groupby('site_id_l').nunique()
Month_122 = long_table2[long_table2['interview_age'] == 122].groupby('site_id_l').nunique()
Month_123 = long_table2[long_table2['interview_age'] == 123].groupby('site_id_l').nunique()
Month_124 = long_table2[long_table2['interview_age'] == 124].groupby('site_id_l').nunique()
Month_125 = long_table2[long_table2['interview_age'] == 125].groupby('site_id_l').nunique()
Month_126 = long_table2[long_table2['interview_age'] == 126].groupby('site_id_l').nunique()
Month_127 = long_table2[long_table2['interview_age'] == 127].groupby('site_id_l').nunique()
Month_128 = long_table2[long_table2['interview_age'] == 128].groupby('site_id_l').nunique()
Month_129 = long_table2[long_table2['interview_age'] == 129].groupby('site_id_l').nunique()
Month_130 = long_table2[long_table2['interview_age'] == 130].groupby('site_id_l').nunique()
Month_131 = long_table2[long_table2['interview_age'] == 131].groupby('site_id_l').nunique()
Month_132 = long_table2[long_table2['interview_age'] == 132].groupby('site_id_l').nunique()
# Out:
# site_id_l
# site01    26
# site02    26
# site03    26
# site04    26
# site05    26
# site06    26
# site07    26
# site08    26
# site09    25
# site10    26
# site11    26
# site12    26
# site13    26
# site14    25
# site15    25
# site16    26
# site17    26
# site18    26
# site19    26
# site20    25
# site21    25
# site22    12
# Name: interview_age, dtype: int64
# site_id_l
# site01     6
# site02     3
# site03     9
# site04     5
# site05     1
# site06     5
# site07     5
# site08     1
# site09     3
# site10     5
# site11     5
# site12    10
# site13     6
# site15     4
# site16    16
# site17     9
# site18     1
# site19     1
# site21     2
# Name: subjectkey, dtype: int64

# %%
table['Site'] = long_table2['site_id_l'].unique()
table['Female'] = gender_F['subjectkey']
table['Male'] = gender_M['subjectkey']
table['Month 107'] = Month_107['subjectkey']
table['Month 108'] = Month_108['subjectkey']
table['Month 109'] = Month_109['subjectkey']
table['Month 110'] = Month_110['subjectkey']
table['Month 111'] = Month_111['subjectkey']
table['Month 112'] = Month_112['subjectkey']
table['Month 113'] = Month_113['subjectkey']
table['Month 114'] = Month_114['subjectkey']
table['Month 115'] = Month_115['subjectkey']
table['Month 116'] = Month_116['subjectkey']
table['Month 117'] = Month_117['subjectkey']
table['Month 118'] = Month_118['subjectkey']
table['Month 119'] = Month_119['subjectkey']
table['Month 120'] = Month_120['subjectkey']
table['Month 121'] = Month_121['subjectkey']
table['Month 122'] = Month_122['subjectkey']
table['Month 123'] = Month_123['subjectkey']
table['Month 124'] = Month_124['subjectkey']
table['Month 125'] = Month_125['subjectkey']
table['Month 126'] = Month_126['subjectkey']
table['Month 127'] = Month_127['subjectkey']
table['Month 128'] = Month_128['subjectkey']
table['Month 129'] = Month_129['subjectkey']
table['Month 130'] = Month_130['subjectkey']
table['Month 131'] = Month_131['subjectkey']
table['Month 132'] = Month_132['subjectkey']
table_df = pd.DataFrame(data = table)
table_df
# Out:
#           Site  Female  Male  Month 107  Month 108  Month 109  Month 110  \
# site01  site06     148   144        6.0       31.0         19        8.0
# site02  site12     214   236        3.0       17.0         11       22.0
# site03  site04     239   224        9.0       40.0         29       27.0
# site04  site16     174   167        5.0       44.0         29       11.0
# site05  site01     127   123        1.0       24.0         14       17.0
# site06  site10     217   209        5.0       24.0         23       23.0
# site07  site20     114   125        5.0       19.0         15       12.0
# site08  site19      73    67        1.0       10.0          7        4.0
# site09  site13     159   140        3.0       16.0         12       15.0
# site10  site07     185   181        5.0       37.0         26       13.0
# site11  site02     141   140        5.0       35.0         24       16.0
# site12  site11     217   221       10.0       42.0         23       13.0
# ...
