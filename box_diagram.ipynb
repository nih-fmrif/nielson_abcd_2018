# %%
import pandas as pd
from pathlib import Path
from IPython.display import display

data_dir = Path('data')
long_table1 = pd.read_pickle(data_dir /'long_table.pkz')
long_table2 = pd.read_pickle(data_dir /'long_table_2.0.pkz')

# %%
# len(long_table1.columns)
fsqc_pass1 = long_table1[long_table1['fsqc_qc'] == 1].groupby('task').nunique()
# fsqc_pass1.head()
mid_qc = fsqc_pass1.subjectkey.loc['mid']
rest_qc = fsqc_pass1.subjectkey.loc['']
display(rest_qc)
sst_qc = fsqc_pass1.subjectkey.loc['sst']
nback_qc = fsqc_pass1.subjectkey.loc['nback']

fsqc_ex1 = long_table1[long_table1['fsqc_qc'] != 1].groupby('task').nunique()
mid_qc_ex = fsqc_ex1.subjectkey.loc['mid']
sst_qc_ex = fsqc_ex1.subjectkey.loc['sst']
nback_qc_ex = fsqc_ex1.subjectkey.loc['nback']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/Anaconda/envs/py3.6/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# /usr/local/Anaconda/envs/py3.6/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [rest] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-3a6aa87f3976> in <module>
#       3 # fsqc_pass1.head()
#       4 mid_qc = fsqc_pass1.subjectkey.loc['mid']
# ...

# %%
fsqc_pass2 = long_table2[long_table2['fsqc_qc'] == 1].groupby('task').nunique()
mid_qc2 = fsqc_pass2.subjectkey.loc['mid']
sst_qc2 = fsqc_pass2.subjectkey.loc['sst']
nback_qc2 = fsqc_pass2.subjectkey.loc['nback']

fsqc_ex2 = long_table2[long_table2['fsqc_qc'] != 1].groupby('task').nunique()
mid_qc2_ex = fsqc_ex2.subjectkey.loc['mid']
sst_qc2_ex = fsqc_ex2.subjectkey.loc['sst']
nback_qc2_ex = fsqc_ex2.subjectkey.loc['nback']

# %%
mid_perform_pass1 = long_table1[long_table1['tfmri_mid_beh_perform.flag'] == 1].groupby('task').nunique()
mid_perform = mid_perform_pass1.subjectkey.loc['mid']

mid_perform_ex1 = long_table1[long_table1['tfmri_mid_beh_perform.flag'] != 1].groupby('task').nunique()
mid_perform_ex = mid_perform_ex1.subjectkey.loc['mid']

sst_perform_pass1 = long_table1[long_table1['tfmri_sst_beh_perform.flag'] == 1].groupby('task').nunique()
sst_perform = sst_perform_pass1.subjectkey.loc['sst']

sst_perform_ex1 = long_table1[long_table1['tfmri_sst_beh_perform.flag'] != 1].groupby('task').nunique()
sst_perform_ex = sst_perform_ex1.subjectkey.loc['sst']

nback_perform_pass1 = long_table1[long_table1['tfmri_sst_beh_perform.flag'] == 1].groupby('task').nunique()
nback_perform = nback_perform_pass1.subjectkey.loc['nback']

nback_perform_ex1 = long_table1[long_table1['tfmri_sst_beh_perform.flag'] != 1].groupby('task').nunique()
nback_perform_ex = nback_perform_ex1.subjectkey.loc['nback']

# %%
mid_perform_pass2 = long_table2[long_table2['tfmri_mid_beh_perform.flag'] == 1].groupby('task').nunique()
mid_perform2 = mid_perform_pass2.subjectkey.loc['mid']

mid_perform_ex2 = long_table2[long_table2['tfmri_mid_beh_perform.flag'] != 1].groupby('task').nunique()
mid_perform2_ex = mid_perform_ex2.subjectkey.loc['mid']

sst_perform_pass2 = long_table2[long_table2['tfmri_sst_beh_perform.flag'] == 1].groupby('task').nunique()
sst_perform2 = sst_perform_pass2.subjectkey.loc['sst']

sst_perform_ex2 = long_table2[long_table2['tfmri_sst_beh_perform.flag'] != 1].groupby('task').nunique()
sst_perform2_ex = sst_perform_ex2.subjectkey.loc['sst']

nback_perform_pass2 = long_table2[long_table2['tfmri_sst_beh_perform.flag'] == 1].groupby('task').nunique()
nback_perform2 = nback_perform_pass2.subjectkey.loc['nback']

nback_perform_ex2 = long_table2[long_table2['tfmri_sst_beh_perform.flag'] != 1].groupby('task').nunique()
nback_perform2_ex = nback_perform_ex2.subjectkey.loc['nback']

# %%
mid_dof_ex1 = long_table1[long_table1['tfmri_mid_all_beta_dof'] <= 200].groupby('task').nunique()
mid_dof_ex = mid_dof_ex1.subjectkey.loc['mid']

mid_dof_pass1 = long_table1[long_table1['tfmri_mid_all_beta_dof'] >= 200].groupby('task').nunique()
mid_dof = mid_dof_pass1.subjectkey.loc['mid']

sst_dof_ex1 = long_table1[long_table1['tfmri_sst_all_beta_dof'] <= 200].groupby('task').nunique()
sst_dof_ex = sst_dof_ex1.subjectkey.loc['sst']

sst_dof_pass1 = long_table1[long_table1['tfmri_sst_all_beta_dof'] >= 200].groupby('task').nunique()
sst_dof = sst_dof_pass1.subjectkey.loc['sst']

nback_dof_ex1 = long_table1[long_table1['tfmri_nback_all_beta_dof'] <= 200].groupby('task').nunique()
nback_dof_ex = nback_dof_ex1.subjectkey.loc['nback']

nback_dof_pass1 = long_table1[long_table1['tfmri_nback_all_beta_dof'] >= 200].groupby('task').nunique()
nback_dof = nback_dof_pass1.subjectkey.loc['nback']

# %%
mid_dof_ex2 = long_table2[long_table2['tfmri_mid_all_beta_dof'] <= 200].groupby('task').nunique()
mid_dof_ex2 = mid_dof_ex2.subjectkey.loc['mid']

mid_dof_pass2 = long_table2[long_table2['tfmri_mid_all_beta_dof'] >= 200].groupby('task').nunique()
mid_dof2 = mid_dof_pass2.subjectkey.loc['mid']

sst_dof_ex2 = long_table2[long_table2['tfmri_sst_all_beta_dof'] <= 200].groupby('task').nunique()
sst_dof_ex2 = sst_dof_ex2.subjectkey.loc['sst']

sst_dof_pass2 = long_table2[long_table2['tfmri_sst_all_beta_dof'] >= 200].groupby('task').nunique()
sst_dof2 = sst_dof_pass2.subjectkey.loc['sst']

nback_dof_ex2 = long_table2[long_table2['tfmri_nback_all_beta_dof'] <= 200].groupby('task').nunique()
nback_dof_ex2 = nback_dof_ex2.subjectkey.loc['nback']

nback_dof_pass2 = long_table2[long_table2['tfmri_nback_all_beta_dof'] >= 200].groupby('task').nunique()
nback_dof2 = nback_dof_pass2.subjectkey.loc['nback']

# %%
box_diagram = {'Inclusion Criteria': ['MID fsqc_qc', 'tfmri_mid_beh_perform.flag', \
                                      'tfmri_mid_all_beta_dof', 'SST fsqc_qc', 'tfmri_sst_beh_perform.flag', \
                                      'tfmri_sst_all_beta_dof', 'nBack fsqc_qc', 'tfmri_nback_beh_perform.flag', \
                                      'tfmri_nback_all_beta_dof'], 'Description of Criteria': \
               ['FreeSurfer QC', 'ABCD Task fMRI MID Behavior', 'ABCD Task fMRI MID Average Beta Weights Part 1', \
                'FreeSurfer QC', 'ABCD Task fMRI SST Behavior', 'ABCD Task fMRI SST Average Beta Weights Part 1', \
                'FreeSurfer QC', 'ABCD Task fMRI nBack Behavior', 'ABCD Task fMRI nback Average Beta Weights Part 1'], \
              '1.1 Data Passing Subjects': [mid_qc, mid_perform, mid_dof, sst_qc, sst_perform, sst_dof, nback_qc, \
                                            nback_perform, nback_dof], '1.1 Data Excluded Subjects': \
               [mid_qc_ex, mid_perform_ex, mid_dof_ex, sst_qc_ex, sst_perform_ex, sst_dof_ex, nback_qc_ex, \
                nback_perform_ex, nback_dof_ex], '2.0 Data Passing Subjects': \
               [mid_qc2, mid_perform2, mid_dof2, sst_qc2, sst_perform2, sst_dof2, nback_qc2, nback_perform2, nback_dof2], \
               '2.0 Data Excluded Subjects': [mid_qc2_ex, mid_perform2_ex, mid_dof_ex2, sst_qc2_ex, sst_perform2_ex, \
                                            sst_dof_ex2, nback_qc2_ex, nback_perform2_ex, nback_dof_ex2]}
box_diagram_df = pd.DataFrame(data=box_diagram)
box_diagram_df
# Out:
#              Inclusion Criteria  \
# 0                   MID fsqc_qc
# 1    tfmri_mid_beh_perform.flag
# 2        tfmri_mid_all_beta_dof
# 3                   SST fsqc_qc
# 4    tfmri_sst_beh_perform.flag
# 5        tfmri_sst_all_beta_dof
# 6                 nBack fsqc_qc
# 7  tfmri_nback_beh_perform.flag
# 8      tfmri_nback_all_beta_dof
#
#                             Description of Criteria  \
# 0                                     FreeSurfer QC
# 1                       ABCD Task fMRI MID Behavior
# 2    ABCD Task fMRI MID Average Beta Weights Part 1
# 3                                     FreeSurfer QC
# 4                       ABCD Task fMRI SST Behavior
# 5    ABCD Task fMRI SST Average Beta Weights Part 1
# 6                                     FreeSurfer QC
# 7                     ABCD Task fMRI nBack Behavior
# 8  ABCD Task fMRI nback Average Beta Weights Part 1
#
#    1.1 Data Passing Subjects  1.1 Data Excluded Subjects  \
# ...
