# %%
from collections import namedtuple
import numpy as np
import pandas as pd
from pathlib import Path

# Display more rows and get rid of the margins
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('max_colwidth',500)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# Display mulitiple values from each cell
# https://stackoverflow.com/a/42476224
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Define paths and functions

# %%
abcd_table_path = './ABCDstudyDEAP/'
data_dir = Path('data')

# %%
def load_abcd_table(path):
    table = pd.read_csv(path, skiprows=[1], header=0, sep='\t')
    labels = pd.read_csv(path, nrows=1, header=0, sep='\t')
    labels = labels.T.reset_index().rename(columns={'index':'name', 0:'doc'})
    return table, labels

def append_abcd_table(path, table=None, label=None, on=None):
    if table is None:
        return load_abcd_table(path)
    if on is None:
        on = ['subjectkey', 'interview_date', 'visit', 'lmt_run']
    new_table, new_label = load_abcd_table(path)
    # Find drop common columns that aren't in the set we're merging on
    drop_cols = label.loc[label.doc.isin(new_label.doc) & ~label.name.isin(on),'name'].values
    new_table.drop(drop_cols, axis=1, inplace=True)
    new_label = new_label[~new_label.name.isin(drop_cols) & ~new_label.name.isin(on)]
    
    # Get table shapes for error checking
    ts = table.shape
    nts = new_table.shape
    ls = label.shape
    nls = new_label.shape
    
    # Merge the tables
    table = table.merge(new_table, how='outer',on=on)
    
    # Check for success
    assert table.shape[0] == ts[0] == nts[0]
    assert table.shape[1] == (ts[1] + nts[1] - len(on))
    
    # Merge labels
    label = pd.concat([label, new_label]).reset_index(drop=True)
    
    assert label.shape[0] == table.shape[1]
    
    return table, label

def load_task_melt_contrasts(paths, contrasts, task_name):
    task_t = None
    task_l = None
    for pp in paths:
        task_t, task_l = append_abcd_table(pp, table=task_t, label=task_l)
        
    # Rearrange columns
    new_col_order = pd.concat([task_l.name[~task_l.doc.str.split('for ').str[1].str.split(' contrast in').str[0].isin(contrasts)],
                               task_l.name[task_l.doc.str.split('for ').str[1].str.split(' contrast in').str[0].isin(contrasts)]]).values
    task_t = task_t.loc[:,new_col_order]
    task_l = task_l.set_index('name').T.loc[:,new_col_order].T.reset_index()
    
    # Manipulate labels to get more information about them
    if task_name == 'nb':
        task_l.loc[task_l.doc.str.split('for ').str[1].str.split(' in').str[0].isin(contrasts), 'contrast'] = task_l.doc.str.split('for ').str[1].str.split(' in').str[0]
        task_l.loc[pd.notnull(task_l.contrast),'roi_code'] = task_l.loc[pd.notnull(task_l.contrast),'name'].str.split('x').str[-1]
        task_l.loc[pd.notnull(task_l.contrast),'hemisphere'] = task_l.loc[pd.notnull(task_l.contrast),'roi_code'].str.split('g').str[0]
        task_l.loc[pd.notnull(task_l.contrast),'roi_num'] = task_l.loc[pd.notnull(task_l.contrast),'roi_code'].str.split('p').str[-1].astype(int)
        task_meta_cols = task_l.name[~task_l.doc.str.split('for ').str[1].str.split(' in').str[0].isin(contrasts)]
    else:
        task_l.loc[task_l.doc.str.split('for ').str[1].str.split(' contrast in').str[0].isin(contrasts), 'contrast'] = task_l.doc.str.split('for ').str[1].str.split(' contrast in').str[0]
        task_l.loc[pd.notnull(task_l.contrast),'roi_code'] = task_l.loc[pd.notnull(task_l.contrast),'name'].str.split('x').str[-1]
        task_l.loc[pd.notnull(task_l.contrast),'hemisphere'] = task_l.loc[pd.notnull(task_l.contrast),'roi_code'].str.split('g').str[0]
        task_l.loc[pd.notnull(task_l.contrast),'roi_num'] = task_l.loc[pd.notnull(task_l.contrast),'roi_code'].str.split('p').str[-1].astype(int)
        task_meta_cols = task_l.name[~task_l.doc.str.split('for ').str[1].str.split(' contrast in').str[0].isin(contrasts)]

    task_t_melt = []
    for contrast in contrasts:
        tmpdf = task_t.loc[:,task_meta_cols]
        tmpdf['contrast'] = contrast
        if task_name == 'nb':
            contrast_cols = task_l.name[task_l.doc.str.split('for ').str[1].str.split(' in').str[0] == contrast].values
        else:
            contrast_cols = task_l.name[task_l.doc.str.split('for ').str[1].str.split(' contrast in').str[0] == contrast].values
        contrast_df = task_t.loc[:,contrast_cols]
        contrast_df.columns = [task_l.loc[task_l.name==cc,'roi_code'].values[0] for cc in contrast_df.columns.values]
        task_t_melt.append(pd.concat([tmpdf,contrast_df], axis=1))
    task_t_melt = pd.concat(task_t_melt)
    task_t_melt['task'] = task_name
    return task_t_melt, task_l

# %% [markdown]
# # Prepare data
# ## Get sex, handedness, age and device data for balancing

# %%
# Get Handedness data
ehis_path = abcd_table_path + 'abcd_ehis01.txt'
ehis = pd.read_csv(ehis_path, skiprows=[1], header=0, sep='\t')
ehis_labels = pd.read_csv(ehis_path, nrows = 1, header = 0, sep='\t')
ehis_labels = ehis_labels.T.reset_index().rename(columns={'index':'name', 0:'doc'})

# %%
ehis_labels
# Out:
#                    name  \
# 0         collection_id
# 1        abcd_ehis01_id
# 2            dataset_id
# 3            subjectkey
# 4        src_subject_id
# 5        interview_date
# 6         interview_age
# 7                gender
# 8             eventname
# 9                ehi_1b
# 10               ehi_2b
# 11               ehi_3b
# 12               ehi_4b
# 13             ehi_time
# 14         ehi_ss_score
# 15     collection_title
# 16  promoted_subjectkey
# 17    study_cohort_name
#
#                                                                                                 doc
# 0                                                                                     collection_id
# 1                                                                                    abcd_ehis01_id
# 2                                                                                        dataset_id
# 3                                     The NDAR Global Unique Identifier (GUID) for research subject
# 4                                                        Subject ID how it's defined in lab/project
# 5   Date on which the interview/genetic test/sampling/imaging/biospecimen was completed. MM/DD/YYYY
# 6                                 Age in months at the time of the interview/test/sampling/imaging.
# 7                                                                                Sex of the subject
# 8                                                   The event name for which the data was collected
# 9                                                                                           Writing
# 10                                                                                         Throwing
# 11                                                                                       Toothbrush
# 12                                                                                            Spoon
# 13                                                                                    Current Time:
# 14                                                                          Handedness score rating
# 15                                                                                 collection_title
# 16                                                                              promoted_subjectkey
# 17                                                                                study_cohort_name

# %%
# Get site data
site_df = pd.read_csv(abcd_table_path + 'abcd_lt01.txt',
                      skiprows = [1],
                      header = 0,
                      sep='\t')

# Get device data
device_df = pd.read_csv(abcd_table_path + 'abcd_mri01.txt',
                        skiprows = [1],
                        header = 0,
                        sep='\t')

# Put the handedness, age, and sex information together with the device data

bal_site_fields = ['abcd_lt01_id',
                   'subjectkey',
                   'eventname',
                   'site_id_l'
                   ]
bal_ehis_fields = ['collection_id',
                   'dataset_id', 
                   'subjectkey',
                   'interview_date',
                   'interview_age', 
                   'gender',
                   'ehi_ss_score',
                   'eventname'
                  ]
bal_device_fields = ['subjectkey',
                     'eventname',
                     'mri_info_visitid',
                     'mri_info_manufacturer',
                     'mri_info_manufacturersmn',
                     'mri_info_deviceserialnumber',
                     'mri_info_magneticfieldstrength',
                     'mri_info_softwareversion'
                    ]

for_balancing = (ehis.loc[:, bal_ehis_fields]
                     .merge(site_df.loc[:,bal_site_fields],
                            how='outer',
                            on=['subjectkey', 'eventname'],
                            indicator='site_indicator')
                     .merge(device_df.loc[:,bal_device_fields],
                            how='outer',
                            on=['subjectkey', 'eventname'],
                            indicator='device_indicator'))

# make sure both merges worked
assert for_balancing.groupby(['site_indicator'])[['subjectkey']].count().loc['both', 'subjectkey'] == len(ehis)
assert for_balancing.groupby(['device_indicator'])[['subjectkey']].count().loc['both', 'subjectkey'] == len(ehis)

for_balancing = for_balancing.drop(['site_indicator', 'device_indicator'], axis=1)

# %% [markdown]
# ## Assemble rs-fMRI dataframe

# %%
# Between network table
bn_t, bn_l = load_abcd_table(abcd_table_path + 'abcd_betnet02.txt')
# Network to subcortical table
ns_t, ns_l = load_abcd_table(abcd_table_path + 'mrirscor02.txt')
# See which columns are in both tables
bn_l.loc[bn_l.doc.isin(ns_l.doc),:]
# Out:
#                                                  name  \
# 0                                       collection_id
# 2                                          dataset_id
# 3                                          subjectkey
# 4                                      src_subject_id
# 5                                      interview_date
# 6                                       interview_age
# 7                                              gender
# 8                                           eventname
# 9                   rsfmri_cor_network.gordon_visitid
# 10                       rsfmri_cor_network.gordon_tr
# 11                   rsfmri_cor_network.gordon_numtrs
# 12                    rsfmri_cor_network.gordon_nvols
# 13          rsfmri_cor_network.gordon_subthresh.nvols
# 14   rsfmri_cor_network.gordon_subthresh.contig.nvols
# 15                 rsfmri_cor_network.gordon_ntpoints
# 16              rsfmri_cor_network.gordon_mean.motion
# 17               rsfmri_cor_network.gordon_max.motion
# 18               rsfmri_cor_network.gordon_mean.trans
# 19                rsfmri_cor_network.gordon_max.trans
# 20                 rsfmri_cor_network.gordon_mean.rot
# 21                  rsfmri_cor_network.gordon_max.rot
# 191                                  collection_title
# 192                               promoted_subjectkey
# 193                                 study_cohort_name
#
#                                                                                                  doc
# 0                                                                                      collection_id
# 2                                                                                         dataset_id
# 3                                      The NDAR Global Unique Identifier (GUID) for research subject
# 4                                                         Subject ID how it's defined in lab/project
# 5    Date on which the interview/genetic test/sampling/imaging/biospecimen was completed. MM/DD/YYYY
# 6                                  Age in months at the time of the interview/test/sampling/imaging.
# 7                                                                                 Sex of the subject
# 8                                                    The event name for which the data was collected
# 9                                                                                         Visit name
# 10                                                                  Pulse repetition time in seconds
# 11                                                                   Number of frames in acquisition
# 12                                                      Number of frames after removing dummy frames
# 13                                                                    Number of frames with FD < 0.2
# 14                  Number of frames with FD < 0.2 and at least 5 contiguous, supra-threshold frames
# 15         Number of frames after excluding outlier frames (based on standard deviation across ROIs)
# 16                                                              Average framewise displacement in mm
# 17                                                              Maximum framewise displacement in mm
# 18                                                               Average framewise translation in mm
# 19                                                               Maximum framewise translation in mm
# 20                                                             Average framewise rotation in radians
# 21                                                             Maximum framewise rotation in radians
# 191                                                                                 collection_title
# 192                                                                              promoted_subjectkey
# 193                                                                                study_cohort_name

# %%
# We'll merge on subjectkey and interview_date, filter out the other columns from ns_t before merging
ns_t.drop(ns_l.loc[ns_l.doc.isin(bn_l.doc),'name'].drop([3,5]).values,
          axis=1,
          inplace=True)

con = bn_t.merge(ns_t,
                 how='outer',
                 on=['subjectkey','interview_date'])

con_l = pd.concat([bn_l, 
                   ns_l[~ns_l.name.isin(bn_l.loc[bn_l.doc.isin(ns_l.doc),'name'].values)]]).reset_index(drop=True)

# %%
# Merge in balancing variables
con = con.merge(for_balancing.loc[:,['subjectkey','eventname','ehi_ss_score', 'site_id_l', 'mri_info_manufacturer',
       'mri_info_manufacturersmn', 'mri_info_deviceserialnumber', 'mri_info_magneticfieldstrength', 'mri_info_softwareversion']], how='left',
          on=['subjectkey','eventname'], indicator=True)

#con_l = con_l.append(pd.DataFrame([{'name':'ehi_ss_score','doc':'Handedness score rating'}]))

# add id for site, scanner, software
con['unique_scanner'] = con.site_id_l + '__' + con.mri_info_deviceserialnumber + '__' + con.mri_info_softwareversion

# %%
con.groupby(['_merge'])[['subjectkey']].count()
con.drop('_merge', 1, inplace=True)
# Out:
#             subjectkey
# _merge
# left_only            0
# right_only           0
# both              4521

# %%
# Get a list of Metric columns
con_meta_cols = ['collection_id', 'dataset_id', 'subjectkey',
            'src_subject_id', 'interview_date', 'interview_age',
            'gender', 'event_name', 'visit', 'rsfm_tr', 'eventname',
            'rsfm_nreps', 'rsfm_numtrs', 'pipeline_version',  'scanner_manufacturer_pd',
            'scanner_type_pd','deviceserialnumber', 'magnetic_field_strength',
            'procdate', 'collection_title', 'promoted_subjectkey',
            'study_cohort_name','ehi_ss_scoreb', 'qc_ok', 'site_id_l', 'mri_info_manufacturer',
       'mri_info_manufacturersmn', 'mri_info_deviceserialnumber', 'mri_info_magneticfieldstrength', 'mri_info_softwareversion']
con_metric_cols = con_l.loc[~con_l.name.isin(con_meta_cols), 'name'].values


# pull out the roi and network names 

con_l['from_network'] = con_l.loc[con_l.name.isin(con_metric_cols),'doc'].str.split('between ').str[1].str.split('network').str[0]
con_l['to'] = con_l.loc[con_l.name.isin(con_metric_cols),'doc'].str.split('between ').str[1].str.split('network').str[1].str.split(' and').str[1].str.replace('ASEG ROI', '')
con_l['roi'] = con_l.loc[con_l.name.isin(con_metric_cols),'doc'].str.split('and ASEG ROI').str[1].str.strip()

con_l['from_network'].unique()
con_l.roi.unique()
# Out:
# array([nan, 'auditory ', 'cingulo-opercular ', 'cingulo-parietal ',
#        'default ', 'dorsal attention ', 'fronto-parietal ', '"none" ',
#        'retrosplenial temporal ', 'sensorimotor hand ',
#        'sensorimotor mouth ', 'salience ', 'ventral attention ',
#        'visual '], dtype=object)
# array([nan, 'left-cerebellum-cortex', 'left-thalamus-proper',
#        'left-caudate', 'left-putamen', 'left-pallidum', 'brain-stem',
#        'left-hippocampus', 'left-amygdala', 'left-accumbens-area',
#        'left-ventraldc', 'right-cerebellum-cortex',
#        'right-thalamus-proper', 'right-caudate', 'right-putamen',
#        'right-pallidum', 'right-hippocampus', 'right-amygdala',
#        'right-accumbens-area', 'right-ventraldc'], dtype=object)

# %%
con.head()
# Out:
#    collection_id  abcd_betnet02_id  dataset_id        subjectkey  \
# 0           2573             20285       17007  NDAR_INVFAFNLCWD
# 1           2573             19693       17007  NDAR_INVB1DNH7JC
# 2           2573             20348       17007  NDAR_INVFPFM6B57
# 3           2573             19414       17007  NDAR_INV96KLPLFJ
# 4           2573             19933       17007  NDAR_INVCW8WDA3J
#
#      src_subject_id interview_date  interview_age gender  \
# 0  NDAR_INVFAFNLCWD     05/08/2017            108      F
# 1  NDAR_INVB1DNH7JC     12/09/2016            121      F
# 2  NDAR_INVFPFM6B57     03/02/2017            108      M
# 3  NDAR_INV96KLPLFJ     07/21/2017            109      M
# 4  NDAR_INVCW8WDA3J     03/31/2017            116      M
#
#                eventname rsfmri_cor_network.gordon_visitid  \
# 0  baseline_year_1_arm_1         S014_INVFAFNLCWD_20170509
# 1  baseline_year_1_arm_1         S053_INVB1DNH7JC_20161211
# 2  baseline_year_1_arm_1         S053_INVFPFM6B57_20170305
# 3  baseline_year_1_arm_1         S011_INV96KLPLFJ_20170731
# 4  baseline_year_1_arm_1         S014_INVCW8WDA3J_20170401
#
#    rsfmri_cor_network.gordon_tr  rsfmri_cor_network.gordon_numtrs  \
# 0                           0.8                            1532.0
# 1                           0.8                            1532.0
# 2                           0.8                            1532.0
# 3                           0.8                            1532.0
# 4                           0.8                            1532.0
#
#    rsfmri_cor_network.gordon_nvols  rsfmri_cor_network.gordon_subthresh.nvols  \
# 0                           1500.0                                     1330.0
# 1                           1500.0                                     1485.0
# 2                           1500.0                                      958.0
# 3                           1500.0                                      410.0
# 4                           1500.0                                     1475.0
#
#    rsfmri_cor_network.gordon_subthresh.contig.nvols  \
# 0                                            1276.0
# 1                                            1485.0
# 2                                             768.0
# 3                                             292.0
# 4                                            1471.0
#
#    rsfmri_cor_network.gordon_ntpoints  rsfmri_cor_network.gordon_mean.motion  \
# 0                              1155.0                               0.129892
# 1                              1377.0                               0.059886
# 2                               603.0                               0.332657
# 3                               105.0                               1.396390
# 4                              1387.0                               0.071670
#
#    rsfmri_cor_network.gordon_max.motion  rsfmri_cor_network.gordon_mean.trans  \
# 0                              5.069193                              0.079314
# 1                              0.766362                              0.039253
# 2                              9.797004                              0.158036
# 3                             13.092856                              0.625400
# 4                              3.325154                              0.050000
#
#    rsfmri_cor_network.gordon_max.trans  rsfmri_cor_network.gordon_mean.rot  \
# 0                             2.522730                            0.050578
# 1                             0.242272                            0.020633
# 2                             8.979014                            0.174621
# 3                             9.843847                            0.770990
# 4                             1.256487                            0.021669
#
#    rsfmri_cor_network.gordon_max.rot  \
# 0                           2.621751
# 1                           0.633536
# 2                           3.525160
# 3                           8.925490
# 4                           2.068667
#
#    rsfmri_cor_network.gordon_auditory_network.gordon_auditory  \
# 0                                                    0.284765
# 1                                                    0.250725
# 2                                                    0.380548
# 3                                                    0.037517
# 4                                                    0.323230
#
#    rsfmri_cor_network.gordon_auditory_network.gordon_cingulooperc  \
# 0                                                        0.156347
# 1                                                        0.084549
# 2                                                        0.190432
# 3                                                        0.114797
# 4                                                        0.128719
#
#    rsfmri_cor_network.gordon_auditory_network.gordon_cinguloparietal  \
# 0                                                          -0.093993
# 1                                                          -0.095535
# 2                                                          -0.070637
# 3                                                           0.134830
# 4                                                          -0.182977
#
#    rsfmri_cor_network.gordon_auditory_network.gordon_default  \
# 0                                                  -0.070397
# 1                                                  -0.016601
# 2                                                  -0.126914
# 3                                                   0.022980
# 4                                                  -0.101072
#
#    rsfmri_cor_network.gordon_auditory_network.gordon_dorsalattn  \
# 0                                                      0.029232
# 1                                                     -0.030409
# 2                                                     -0.039653
# 3                                                      0.089247
# 4                                                     -0.061133
#
#    rsfmri_cor_network.gordon_auditory_network.gordon_frontoparietal  \
# 0                                                         -0.057807
# 1                                                         -0.053887
# 2                                                         -0.078214
# 3                                                          0.183115
# 4                                                         -0.105782
#
#    rsfmri_cor_network.gordon_auditory_network.gordon_none  \
# 0                                               -0.031698
# 1                                                0.002907
# 2                                               -0.005681
# 3                                                0.015363
# 4                                                0.032871
#
#    rsfmri_cor_network.gordon_auditory_network.gordon_retrosplenialtemporal  \
# 0                                                                -0.023297
# 1                                                                -0.021390
# 2                                                                -0.016887
# 3                                                                -0.011226
# 4                                                                -0.091307
#
#    rsfmri_cor_network.gordon_auditory_network.gordon_smhand  \
# 0                                                  0.173780
# 1                                                  0.134312
# 2                                                  0.093760
# 3                                                 -0.099510
# 4                                                  0.190210
#
#    rsfmri_cor_network.gordon_auditory_network.gordon_smmouth  \
# 0                                                   0.219575
# 1                                                   0.099950
# 2                                                   0.276732
# 3                                                  -0.106402
# 4                                                   0.145613
#
#    rsfmri_cor_network.gordon_auditory_network.gordon_salience  \
# 0                                                   -0.029166
# 1                                                    0.000864
# 2                                                    0.111927
# 3                                                    0.250010
# 4                                                   -0.052756
#
#    rsfmri_cor_network.gordon_auditory_network.gordon_ventralattn  \
# 0                                                       0.052155
# 1                                                       0.043836
# 2                                                       0.045836
# 3                                                      -0.029930
# 4                                                       0.106541
#
#    rsfmri_cor_network.gordon_auditory_network.gordon_visual  \
# 0                                                 -0.036475
# 1                                                 -0.041651
# 2                                                  0.065940
# 3                                                 -0.113379
# 4                                                 -0.019271
#
#    rsfmri_cor_network.gordon_cingulooperc_network.gordon_auditory  \
# 0                                                        0.156347
# 1                                                        0.084549
# 2                                                        0.190432
# 3                                                        0.114797
# 4                                                        0.128719
#
#    rsfmri_cor_network.gordon_cingulooperc_network.gordon_cingulooperc  \
# 0                                                            0.393032
# 1                                                            0.328209
# 2                                                            0.355454
# 3                                                            0.092950
# 4                                                            0.322599
#
#    rsfmri_cor_network.gordon_cingulooperc_network.gordon_cinguloparietal  \
# 0                                                              -0.295029
# 1                                                               0.105001
# 2                                                               0.082313
# 3                                                               0.127488
# 4                                                               0.040506
#
#    rsfmri_cor_network.gordon_cingulooperc_network.gordon_default  \
# 0                                                      -0.090206
# 1                                                      -0.177221
# 2                                                      -0.195421
# 3                                                      -0.024228
# 4                                                      -0.124315
#
#    rsfmri_cor_network.gordon_cingulooperc_network.gordon_dorsalattn  \
# 0                                                          0.203620
# 1                                                          0.090584
# 2                                                          0.081814
# 3                                                          0.123201
# 4                                                          0.049621
#
#    rsfmri_cor_network.gordon_cingulooperc_network.gordon_frontoparietal  \
# 0                                                              0.054845
# 1                                                             -0.041297
# 2                                                             -0.048005
# 3                                                              0.149851
# 4                                                              0.041830
#
#    rsfmri_cor_network.gordon_cingulooperc_network.gordon_none  \
# 0                                                    0.023530
# 1                                                   -0.070354
# 2                                                   -0.020312
# 3                                                    0.018504
# 4                                                    0.007417
#
#    rsfmri_cor_network.gordon_cingulooperc_network.gordon_retrosplenialtemporal  \
# 0                                                                    -0.204698
# 1                                                                    -0.047980
# 2                                                                    -0.035422
# 3                                                                     0.014761
# 4                                                                    -0.109789
#
#    rsfmri_cor_network.gordon_cingulooperc_network.gordon_smhand  \
# 0                                                      0.038452
# 1                                                      0.030357
# 2                                                      0.050133
# 3                                                     -0.120114
# 4                                                      0.130713
#
#    rsfmri_cor_network.gordon_cingulooperc_network.gordon_smmouth  \
# 0                                                       0.123215
# 1                                                       0.103741
# 2                                                       0.016089
# 3                                                      -0.080853
# 4                                                       0.084298
#
#    rsfmri_cor_network.gordon_cingulooperc_network.gordon_salience  \
# 0                                                        0.201627
# 1                                                        0.163406
# 2                                                        0.274916
# 3                                                        0.261719
# 4                                                        0.194868
#
#    rsfmri_cor_network.gordon_cingulooperc_network.gordon_ventralattn  \
# 0                                                           0.117892
# 1                                                          -0.067356
# 2                                                           0.047028
# 3                                                          -0.067559
# 4                                                           0.022106
#
#    rsfmri_cor_network.gordon_cingulooperc_network.gordon_visual  \
# 0                                                     -0.083334
# 1                                                      0.117923
# 2                                                      0.090941
# 3                                                     -0.059397
# 4                                                     -0.121952
#
#    rsfmri_cor_network.gordon_cinguloparietal_network.gordon_auditory  \
# 0                                                          -0.093993
# 1                                                          -0.095535
# 2                                                          -0.070637
# 3                                                           0.134830
# 4                                                          -0.182977
#
#    rsfmri_cor_network.gordon_cinguloparietal_network.gordon_cingulooperc  \
# 0                                                              -0.295029
# 1                                                               0.105001
# 2                                                               0.082313
# 3                                                               0.127488
# 4                                                               0.040506
#
#    rsfmri_cor_network.gordon_cinguloparietal_network.gordon_cinguloparietal  \
# 0                                                                  0.965534
# 1                                                                  0.920255
# 2                                                                  1.011163
# 3                                                                  0.193483
# 4                                                                  0.875905
#
#    rsfmri_cor_network.gordon_cinguloparietal_network.gordon_default  \
# 0                                                          0.033310
# 1                                                          0.001633
# 2                                                          0.135080
# 3                                                          0.187921
# 4                                                         -0.044525
#
#    rsfmri_cor_network.gordon_cinguloparietal_network.gordon_dorsalattn  \
# 0                                                            -0.204631
# 1                                                             0.073545
# 2                                                            -0.061983
# 3                                                             0.200261
# 4                                                             0.143924
#
#    rsfmri_cor_network.gordon_cinguloparietal_network.gordon_frontoparietal  \
# 0                                                                -0.165714
# 1                                                                -0.001268
# 2                                                                 0.058259
# 3                                                                 0.329051
# 4                                                                 0.065822
#
#    rsfmri_cor_network.gordon_cinguloparietal_network.gordon_none  \
# 0                                                      -0.110842
# 1                                                      -0.056710
# 2                                                       0.062170
# 3                                                       0.036515
# 4                                                      -0.079774
#
#    rsfmri_cor_network.gordon_cinguloparietal_network.gordon_retrosplenialtemporal  \
# 0                                                                        0.361974
# 1                                                                        0.114112
# 2                                                                        0.192984
# 3                                                                        0.025722
# 4                                                                        0.138283
#
#    rsfmri_cor_network.gordon_cinguloparietal_network.gordon_smhand  \
# 0                                                        -0.076162
# 1                                                        -0.097801
# 2                                                        -0.195917
# 3                                                        -0.142441
# 4                                                        -0.082374
#
#    rsfmri_cor_network.gordon_cinguloparietal_network.gordon_smmouth  \
# 0                                                         -0.102428
# 1                                                         -0.038763
# 2                                                         -0.089181
# 3                                                         -0.225840
# 4                                                         -0.019857
#
#    rsfmri_cor_network.gordon_cinguloparietal_network.gordon_salience  \
# 0                                                          -0.216206
# 1                                                           0.162460
# 2                                                           0.229704
# 3                                                           0.439816
# 4                                                           0.135008
#
#    rsfmri_cor_network.gordon_cinguloparietal_network.gordon_ventralattn  \
# 0                                                             -0.301976
# 1                                                             -0.079589
# 2                                                              0.024987
# 3                                                              0.077885
# 4                                                             -0.255956
#
#    rsfmri_cor_network.gordon_cinguloparietal_network.gordon_visual  \
# 0                                                         0.211662
# 1                                                         0.062099
# 2                                                        -0.023508
# 3                                                        -0.298787
# 4                                                         0.124679
#
#    rsfmri_cor_network.gordon_default_network.gordon_auditory  \
# 0                                                  -0.070397
# 1                                                  -0.016601
# 2                                                  -0.126914
# 3                                                   0.022980
# 4                                                  -0.101072
#
#    rsfmri_cor_network.gordon_default_network.gordon_cingulooperc  \
# 0                                                      -0.090206
# 1                                                      -0.177221
# 2                                                      -0.195421
# 3                                                      -0.024228
# 4                                                      -0.124315
#
#    rsfmri_cor_network.gordon_default_network.gordon_cinguloparietal  \
# 0                                                          0.033310
# 1                                                          0.001633
# 2                                                          0.135080
# 3                                                          0.187921
# 4                                                         -0.044525
#
#    rsfmri_cor_network.gordon_default_network.gordon_default  \
# 0                                                  0.215323
# 1                                                  0.256923
# 2                                                  0.369382
# 3                                                  0.120268
# 4                                                  0.437718
#
#    rsfmri_cor_network.gordon_default_network.gordon_dorsalattn  \
# 0                                                    -0.117712
# 1                                                    -0.128658
# 2                                                    -0.200216
# 3                                                     0.046162
# 4                                                    -0.169556
#
#    rsfmri_cor_network.gordon_default_network.gordon_frontoparietal  \
# 0                                                         0.029424
# 1                                                         0.040779
# 2                                                         0.151926
# 3                                                         0.132841
# 4                                                         0.140022
#
#    rsfmri_cor_network.gordon_default_network.gordon_none  \
# 0                                               0.074619
# 1                                               0.090794
# 2                                               0.097244
# 3                                              -0.004075
# 4                                               0.100174
#
#    rsfmri_cor_network.gordon_default_network.gordon_retrosplenialtemporal  \
# 0                                                                0.012429
# 1                                                               -0.019971
# 2                                                               -0.084802
# 3                                                               -0.021025
# 4                                                                0.248820
#
#    rsfmri_cor_network.gordon_default_network.gordon_smhand  \
# 0                                                -0.070127
# 1                                                -0.024147
# 2                                                -0.096693
# 3                                                 0.026372
# 4                                                -0.187628
#
#    rsfmri_cor_network.gordon_default_network.gordon_smmouth  \
# 0                                                 -0.095273
# 1                                                 -0.121911
# 2                                                 -0.019020
# 3                                                 -0.093562
# 4                                                  0.001530
#
#    rsfmri_cor_network.gordon_default_network.gordon_salience  \
# 0                                                   0.064150
# 1                                                   0.040570
# 2                                                  -0.048500
# 3                                                   0.106464
# 4                                                   0.223937
#
#    rsfmri_cor_network.gordon_default_network.gordon_ventralattn  \
# 0                                                      0.099217
# 1                                                      0.132224
# 2                                                      0.164075
# 3                                                      0.117277
# 4                                                      0.150070
#
#    rsfmri_cor_network.gordon_default_network.gordon_visual  \
# 0                                                -0.139325
# 1                                                -0.223194
# 2                                                -0.355794
# 3                                                -0.145115
# 4                                                -0.224425
#
#    rsfmri_cor_network.gordon_dorsalattn_network.gordon_auditory  \
# 0                                                      0.029232
# 1                                                     -0.030409
# 2                                                     -0.039653
# 3                                                      0.089247
# 4                                                     -0.061133
#
#    rsfmri_cor_network.gordon_dorsalattn_network.gordon_cingulooperc  \
# 0                                                          0.203620
# 1                                                          0.090584
# 2                                                          0.081814
# 3                                                          0.123201
# 4                                                          0.049621
#
#    rsfmri_cor_network.gordon_dorsalattn_network.gordon_cinguloparietal  \
# 0                                                            -0.204631
# 1                                                             0.073545
# 2                                                            -0.061983
# 3                                                             0.200261
# 4                                                             0.143924
#
#    rsfmri_cor_network.gordon_dorsalattn_network.gordon_default  \
# 0                                                    -0.117712
# 1                                                    -0.128658
# 2                                                    -0.200216
# 3                                                     0.046162
# 4                                                    -0.169556
#
#    rsfmri_cor_network.gordon_dorsalattn_network.gordon_dorsalattn  \
# 0                                                        0.342119
# 1                                                        0.213161
# 2                                                        0.215078
# 3                                                        0.212484
# 4                                                        0.202758
#
#    rsfmri_cor_network.gordon_dorsalattn_network.gordon_frontoparietal  \
# 0                                                            0.086981
# 1                                                            0.007179
# 2                                                           -0.080708
# 3                                                            0.209415
# 4                                                            0.015258
#
#    rsfmri_cor_network.gordon_dorsalattn_network.gordon_none  \
# 0                                                 -0.026875
# 1                                                 -0.053186
# 2                                                 -0.066953
# 3                                                 -0.035277
# 4                                                 -0.065753
#
#    rsfmri_cor_network.gordon_dorsalattn_network.gordon_retrosplenialtemporal  \
# 0                                                                  -0.079474
# 1                                                                  -0.022009
# 2                                                                   0.036005
# 3                                                                  -0.029941
# 4                                                                  -0.005679
#
#    rsfmri_cor_network.gordon_dorsalattn_network.gordon_smhand  \
# 0                                                    0.032597
# 1                                                    0.043894
# 2                                                    0.024237
# 3                                                   -0.054510
# 4                                                    0.050918
#
#    rsfmri_cor_network.gordon_dorsalattn_network.gordon_smmouth  \
# 0                                                     0.001669
# 1                                                     0.002164
# 2                                                    -0.067388
# 3                                                     0.017776
# 4                                                    -0.029016
#
#    rsfmri_cor_network.gordon_dorsalattn_network.gordon_salience  \
# 0                                                      0.103905
# 1                                                      0.031236
# 2                                                     -0.016212
# 3                                                      0.462610
# 4                                                     -0.086285
#
#    rsfmri_cor_network.gordon_dorsalattn_network.gordon_ventralattn  \
# 0                                                        -0.035115
# 1                                                        -0.082104
# 2                                                        -0.121868
# 3                                                        -0.046064
# 4                                                        -0.128646
#
#    rsfmri_cor_network.gordon_dorsalattn_network.gordon_visual  \
# 0                                                    0.001015
# 1                                                    0.072768
# 2                                                    0.155221
# 3                                                   -0.026444
# 4                                                    0.075490
#
#    rsfmri_cor_network.gordon_frontoparietal_network.gordon_auditory  \
# 0                                                         -0.057807
# 1                                                         -0.053887
# 2                                                         -0.078214
# 3                                                          0.183115
# 4                                                         -0.105782
#
#    rsfmri_cor_network.gordon_frontoparietal_network.gordon_cingulooperc  \
# 0                                                              0.054845
# 1                                                             -0.041297
# 2                                                             -0.048005
# 3                                                              0.149851
# 4                                                              0.041830
#
#    rsfmri_cor_network.gordon_frontoparietal_network.gordon_cinguloparietal  \
# 0                                                                -0.165714
# 1                                                                -0.001268
# 2                                                                 0.058259
# 3                                                                 0.329051
# 4                                                                 0.065822
#
#    rsfmri_cor_network.gordon_frontoparietal_network.gordon_default  \
# 0                                                         0.029424
# 1                                                         0.040779
# 2                                                         0.151926
# 3                                                         0.132841
# 4                                                         0.140022
#
#    rsfmri_cor_network.gordon_frontoparietal_network.gordon_dorsalattn  \
# 0                                                            0.086981
# 1                                                            0.007179
# 2                                                           -0.080708
# 3                                                            0.209415
# 4                                                            0.015258
#
#    rsfmri_cor_network.gordon_frontoparietal_network.gordon_frontoparietal  \
# 0                                                                0.247007
# 1                                                                0.161504
# 2                                                                0.211753
# 3                                                                0.304825
# 4                                                                0.422820
#
#    rsfmri_cor_network.gordon_frontoparietal_network.gordon_none  \
# 0                                                      0.053188
# 1                                                      0.006861
# 2                                                      0.068733
# 3                                                      0.003643
# 4                                                      0.034660
#
#    rsfmri_cor_network.gordon_frontoparietal_network.gordon_retrosplenialtemporal  \
# 0                                                                      -0.197616
# 1                                                                      -0.026663
# 2                                                                      -0.092172
# 3                                                                      -0.075375
# 4                                                                      -0.027063
#
#    rsfmri_cor_network.gordon_frontoparietal_network.gordon_smhand  \
# 0                                                       -0.112014
# 1                                                       -0.105702
# 2                                                       -0.032734
# 3                                                       -0.102784
# 4                                                       -0.164615
#
#    rsfmri_cor_network.gordon_frontoparietal_network.gordon_smmouth  \
# 0                                                        -0.146500
# 1                                                        -0.044669
# 2                                                        -0.123183
# 3                                                        -0.166056
# 4                                                        -0.087160
#
#    rsfmri_cor_network.gordon_frontoparietal_network.gordon_salience  \
# 0                                                          0.086002
# 1                                                         -0.041403
# 2                                                          0.043958
# 3                                                          0.534628
# 4                                                          0.407825
#
#    rsfmri_cor_network.gordon_frontoparietal_network.gordon_ventralattn  \
# 0                                                             0.060314
# 1                                                             0.018308
# 2                                                             0.124518
# 3                                                             0.008405
# 4                                                             0.091880
#
#    rsfmri_cor_network.gordon_frontoparietal_network.gordon_visual  \
# 0                                                       -0.145860
# 1                                                       -0.082191
# 2                                                       -0.235263
# 3                                                       -0.216385
# 4                                                       -0.252252
#
#    rsfmri_cor_network.gordon_none_network.gordon_auditory  \
# 0                                               -0.031698
# 1                                                0.002907
# 2                                               -0.005681
# 3                                                0.015363
# 4                                                0.032871
#
#    rsfmri_cor_network.gordon_none_network.gordon_cingulooperc  \
# 0                                                    0.023530
# 1                                                   -0.070354
# 2                                                   -0.020312
# 3                                                    0.018504
# 4                                                    0.007417
#
#    rsfmri_cor_network.gordon_none_network.gordon_cinguloparietal  \
# 0                                                      -0.110842
# 1                                                      -0.056710
# 2                                                       0.062170
# 3                                                       0.036515
# 4                                                      -0.079774
#
#    rsfmri_cor_network.gordon_none_network.gordon_default  \
# 0                                               0.074619
# 1                                               0.090794
# 2                                               0.097244
# 3                                              -0.004075
# 4                                               0.100174
#
#    rsfmri_cor_network.gordon_none_network.gordon_dorsalattn  \
# 0                                                 -0.026875
# 1                                                 -0.053186
# 2                                                 -0.066953
# 3                                                 -0.035277
# 4                                                 -0.065753
#
#    rsfmri_cor_network.gordon_none_network.gordon_frontoparietal  \
# 0                                                      0.053188
# 1                                                      0.006861
# 2                                                      0.068733
# 3                                                      0.003643
# 4                                                      0.034660
#
#    rsfmri_cor_network.gordon_none_network.gordon_none  \
# 0                                            0.062872
# 1                                            0.075530
# 2                                            0.050417
# 3                                            0.006861
# 4                                            0.063816
#
#    rsfmri_cor_network.gordon_none_network.gordon_retrosplenialtemporal  \
# 0                                                            -0.057569
# 1                                                             0.065165
# 2                                                             0.016921
# 3                                                             0.068916
# 4                                                             0.040869
#
#    rsfmri_cor_network.gordon_none_network.gordon_smhand  \
# 0                                             -0.044441
# 1                                              0.005748
# 2                                             -0.006646
# 3                                             -0.068553
# 4                                             -0.013367
#
#    rsfmri_cor_network.gordon_none_network.gordon_smmouth  \
# 0                                              -0.029679
# 1                                              -0.025175
# 2                                              -0.053249
# 3                                              -0.126005
# 4                                               0.020166
#
#    rsfmri_cor_network.gordon_none_network.gordon_salience  \
# 0                                                0.072628
# 1                                               -0.008928
# 2                                                0.036060
# 3                                               -0.054248
# 4                                                0.045516
#
#    rsfmri_cor_network.gordon_none_network.gordon_ventralattn  \
# 0                                                   0.112363
# 1                                                   0.045383
# 2                                                   0.064278
# 3                                                   0.016275
# 4                                                   0.083449
#
#    rsfmri_cor_network.gordon_none_network.gordon_visual  \
# 0                                             -0.100274
# 1                                             -0.070016
# 2                                             -0.116026
# 3                                             -0.068044
# 4                                             -0.115346
#
#    rsfmri_cor_network.gordon_retrosplenialtemporal_network.gordon_auditory  \
# 0                                                                -0.023297
# 1                                                                -0.021390
# 2                                                                -0.016887
# 3                                                                -0.011226
# 4                                                                -0.091307
#
#    rsfmri_cor_network.gordon_retrosplenialtemporal_network.gordon_cingulooperc  \
# 0                                                                    -0.204698
# 1                                                                    -0.047980
# 2                                                                    -0.035422
# 3                                                                     0.014761
# 4                                                                    -0.109789
#
#    rsfmri_cor_network.gordon_retrosplenialtemporal_network.gordon_cinguloparietal  \
# 0                                                                        0.361974
# 1                                                                        0.114112
# 2                                                                        0.192984
# 3                                                                        0.025722
# 4                                                                        0.138283
#
#    rsfmri_cor_network.gordon_retrosplenialtemporal_network.gordon_default  \
# 0                                                                0.012429
# 1                                                               -0.019971
# 2                                                               -0.084802
# 3                                                               -0.021025
# 4                                                                0.248820
#
#    rsfmri_cor_network.gordon_retrosplenialtemporal_network.gordon_dorsalattn  \
# 0                                                                  -0.079474
# 1                                                                  -0.022009
# 2                                                                   0.036005
# 3                                                                  -0.029941
# 4                                                                  -0.005679
#
#    rsfmri_cor_network.gordon_retrosplenialtemporal_network.gordon_frontoparietal  \
# 0                                                                      -0.197616
# 1                                                                      -0.026663
# 2                                                                      -0.092172
# 3                                                                      -0.075375
# 4                                                                      -0.027063
#
#    rsfmri_cor_network.gordon_retrosplenialtemporal_network.gordon_none  \
# 0                                                            -0.057569
# 1                                                             0.065165
# 2                                                             0.016921
# 3                                                             0.068916
# 4                                                             0.040869
#
#    rsfmri_cor_network.gordon_retrosplenialtemporal_network.gordon_retrosplenialtemporal  \
# 0                                                                              0.464947
# 1                                                                              0.534102
# 2                                                                              0.768797
# 3                                                                              0.028165
# 4                                                                              0.699142
#
#    rsfmri_cor_network.gordon_retrosplenialtemporal_network.gordon_smhand  \
# 0                                                               0.046712
# 1                                                              -0.032418
# 2                                                              -0.043963
# 3                                                              -0.111425
# 4                                                              -0.079942
#
#    rsfmri_cor_network.gordon_retrosplenialtemporal_network.gordon_smmouth  \
# 0                                                                0.039672
# 1                                                                0.047904
# 2                                                               -0.109891
# 3                                                               -0.131754
# 4                                                                0.031798
#
#    rsfmri_cor_network.gordon_retrosplenialtemporal_network.gordon_salience  \
# 0                                                                -0.118486
# 1                                                                -0.155654
# 2                                                                 0.065775
# 3                                                                -0.090645
# 4                                                                -0.025522
#
#    rsfmri_cor_network.gordon_retrosplenialtemporal_network.gordon_ventralattn  \
# 0                                                                   -0.169003
# 1                                                                   -0.062839
# 2                                                                   -0.178856
# 3                                                                    0.009853
# 4                                                                   -0.092779
#
#    rsfmri_cor_network.gordon_retrosplenialtemporal_network.gordon_visual  \
# 0                                                               0.174500
# 1                                                               0.128075
# 2                                                               0.328894
# 3                                                              -0.057501
# ...
# 0                                                       0.163604
# 1                                                       0.101416
# 2                                                      -0.056154
# 3                                                      -0.138895
# 4                                                      -0.160923
#
#    rsfmri_cor_network.gordon_ventralattn_subcort.aseg_putamen.lh  \
# 0                                                       0.018917
# 1                                                      -0.095437
# 2                                                      -0.013134
# 3                                                       0.147228
# 4                                                      -0.033397
#
#    rsfmri_cor_network.gordon_ventralattn_subcort.aseg_pallidum.lh  \
# 0                                                        0.000871
# 1                                                       -0.101497
# 2                                                        0.040985
# 3                                                       -0.221569
# 4                                                       -0.208148
#
#    rsfmri_cor_network.gordon_ventralattn_subcort.aseg_brain.stem  \
# 0                                                       0.161542
# 1                                                       0.132888
# 2                                                       0.100488
# 3                                                      -0.252465
# 4                                                       0.063973
#
#    rsfmri_cor_network.gordon_ventralattn_subcort.aseg_hippocampus.lh  \
# 0                                                          -0.085555
# 1                                                           0.153321
# 2                                                           0.447588
# 3                                                          -0.226160
# 4                                                          -0.120474
#
#    rsfmri_cor_network.gordon_ventralattn_subcort.aseg_amygdala.lh  \
# 0                                                       -0.051892
# 1                                                        0.114010
# 2                                                       -0.028932
# 3                                                        0.242000
# 4                                                        0.132013
#
#    rsfmri_cor_network.gordon_ventralattn_subcort.aseg_accumbens.area.lh  \
# 0                                                              0.063017
# 1                                                             -0.128381
# 2                                                             -0.122937
# 3                                                              0.819847
# 4                                                             -0.080514
#
#    rsfmri_cor_network.gordon_ventralattn_subcort.aseg_ventraldc.lh  \
# 0                                                         0.230201
# 1                                                        -0.043313
# 2                                                         0.384675
# 3                                                        -0.001450
# 4                                                        -0.334411
#
#    rsfmri_cor_network.gordon_ventralattn_subcort.aseg_cerebellum.cortex.rh  \
# 0                                                                 0.246351
# 1                                                                 0.031487
# 2                                                                 0.036482
# 3                                                                -0.209398
# 4                                                                 0.007254
#
#    rsfmri_cor_network.gordon_ventralattn_subcort.aseg_thalamus.proper.rh  \
# 0                                                              -0.197402
# 1                                                              -0.094064
# 2                                                               0.086431
# 3                                                               0.589441
# 4                                                               0.067215
#
#    rsfmri_cor_network.gordon_ventralattn_subcort.aseg_caudate.rh  \
# 0                                                      -0.067848
# 1                                                      -0.000732
# 2                                                      -0.041860
# 3                                                       0.343237
# 4                                                      -0.045644
#
#    rsfmri_cor_network.gordon_ventralattn_subcort.aseg_putamen.rh  \
# 0                                                      -0.280550
# 1                                                       0.050775
# 2                                                       0.018396
# 3                                                       0.262995
# 4                                                       0.090518
#
#    rsfmri_cor_network.gordon_ventralattn_subcort.aseg_pallidum.rh  \
# 0                                                        0.463197
# 1                                                       -0.018820
# 2                                                        0.157262
# 3                                                        0.386600
# 4                                                        0.324851
#
#    rsfmri_cor_network.gordon_ventralattn_subcort.aseg_hippocampus.rh  \
# 0                                                           0.018441
# 1                                                          -0.074358
# 2                                                           0.278957
# 3                                                           0.143040
# 4                                                           0.288542
#
#    rsfmri_cor_network.gordon_ventralattn_subcort.aseg_amygdala.rh  \
# 0                                                       -0.254142
# 1                                                        0.061206
# 2                                                       -0.182677
# 3                                                        0.076529
# 4                                                       -0.075458
#
#    rsfmri_cor_network.gordon_ventralattn_subcort.aseg_accumbens.area.rh  \
# 0                                                             -0.105425
# 1                                                             -0.020172
# 2                                                              0.125364
# 3                                                              0.391693
# 4                                                              0.127286
#
#    rsfmri_cor_network.gordon_ventralattn_subcort.aseg_ventraldc.rh  \
# 0                                                        -0.036393
# 1                                                         0.031208
# 2                                                         0.159979
# 3                                                         0.211717
# 4                                                         0.077543
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_cerebellum.cortex.lh  \
# 0                                                            0.279558
# 1                                                            0.049153
# 2                                                           -0.027378
# 3                                                            0.302863
# 4                                                            0.294312
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_thalamus.proper.lh  \
# 0                                                          0.016015
# 1                                                         -0.018625
# 2                                                         -0.140202
# 3                                                         -0.383448
# 4                                                         -0.074218
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_caudate.lh  \
# 0                                                 -0.031766
# 1                                                  0.025928
# 2                                                 -0.005628
# 3                                                 -0.554359
# 4                                                  0.115616
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_putamen.lh  \
# 0                                                 -0.266500
# 1                                                  0.098186
# 2                                                  0.061303
# 3                                                  0.328735
# 4                                                  0.412669
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_pallidum.lh  \
# 0                                                  -0.158404
# 1                                                  -0.102036
# 2                                                   0.104176
# 3                                                   0.048113
# 4                                                   0.033909
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_brain.stem  \
# 0                                                  0.052673
# 1                                                  0.085785
# 2                                                 -0.339148
# 3                                                 -0.470588
# 4                                                 -0.159405
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_hippocampus.lh  \
# 0                                                     -0.170665
# 1                                                      0.118881
# 2                                                     -0.106454
# 3                                                     -0.268470
# 4                                                     -0.163959
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_amygdala.lh  \
# 0                                                  -0.099793
# 1                                                  -0.010770
# 2                                                  -0.096085
# 3                                                  -0.195061
# 4                                                  -0.172996
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_accumbens.area.lh  \
# 0                                                         0.090702
# 1                                                        -0.088134
# 2                                                        -0.107894
# 3                                                        -0.385807
# 4                                                        -0.030877
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_ventraldc.lh  \
# 0                                                    0.100621
# 1                                                    0.137857
# 2                                                    0.275814
# 3                                                   -0.190587
# 4                                                    0.077017
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_cerebellum.cortex.rh  \
# 0                                                           -0.208546
# 1                                                           -0.086428
# 2                                                           -0.183790
# 3                                                           -0.527221
# 4                                                           -0.035824
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_thalamus.proper.rh  \
# 0                                                          0.071606
# 1                                                         -0.093467
# 2                                                          0.160254
# 3                                                         -0.601244
# 4                                                         -0.081214
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_caudate.rh  \
# 0                                                  0.090496
# 1                                                  0.156284
# 2                                                  0.134130
# 3                                                  0.140034
# 4                                                 -0.039095
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_putamen.rh  \
# 0                                                  0.060321
# 1                                                  0.256997
# 2                                                 -0.102753
# 3                                                  0.324054
# 4                                                  0.123559
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_pallidum.rh  \
# 0                                                  -0.083315
# 1                                                   0.078311
# 2                                                   0.022887
# 3                                                  -0.130881
# 4                                                  -0.113112
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_hippocampus.rh  \
# 0                                                     -0.056217
# 1                                                      0.035550
# 2                                                     -0.039317
# 3                                                      0.091736
# 4                                                     -0.019897
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_amygdala.rh  \
# 0                                                  -0.120456
# 1                                                   0.102291
# 2                                                  -0.190354
# 3                                                  -1.249221
# 4                                                  -0.093283
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_accumbens.area.rh  \
# 0                                                        -0.088239
# 1                                                         0.075920
# 2                                                         0.074571
# 3                                                         0.012331
# 4                                                        -0.050826
#
#    rsfmri_cor_network.gordon_visual_subcort.aseg_ventraldc.rh  ehi_ss_score  \
# 0                                                   -0.082506             1
# 1                                                   -0.088098             1
# 2                                                   -0.517087             1
# 3                                                   -0.078939             1
# 4                                                    0.144582             1
#
#   site_id_l mri_info_manufacturer mri_info_manufacturersmn  \
# 0    site16               SIEMENS                   Prisma
# 1    site21               SIEMENS               Prisma_fit
# 2    site21               SIEMENS               Prisma_fit
# 3    site03               SIEMENS                   Prisma
# 4    site16               SIEMENS                   Prisma
#
#   mri_info_deviceserialnumber  mri_info_magneticfieldstrength  \
# 0                       66105                             3.0
# 1                       67084                             3.0
# 2                       67084                             3.0
# 3                      166003                             3.0
# 4                       66105                             3.0
#
#   mri_info_softwareversion                unique_scanner
# 0             syngo MR E11   site16__66105__syngo MR E11
# 1             syngo MR E11   site21__67084__syngo MR E11
# 2             syngo MR E11   site21__67084__syngo MR E11
# 3             syngo MR E11  site03__166003__syngo MR E11
# 4             syngo MR E11   site16__66105__syngo MR E11

# %% [markdown]
# ## Assemble imaging tables

# %%
image_tbls = ["abcd_smrip101", "abcd_smrip201", "abcd_dti_p101", "abcd_dti_p201",
 "mri_rsi_p102", "mri_rsi_p202", "abcd_midr1bwp101", "abcd_midr1bwp201",
 "midr2bwp101", "midr2bwp201", "mrisstr1bw01", "mrisstr2bw01", "nbackr101",
 "nbackr201", "abcd_mrirstv02", "midaparc02", "midaparcp202", 
 "abcd_midasemp101", "abcd_midasemp201", "abcd_midsemp101",
 "abcd_midsemp201", "abcd_midr2semp101", "abcd_midr2semp201",
 "mrisst02", "mrisstsem01", "mrisstr1sem01", "mrisstr2bwsem01",
 "nback_bwroi02", "nbackallsem01", "nbackr1sem01", "nbackr2sem01",
 "dmriqc01", "abcd_mid02", "abcd_sst02", "abcd_mrinback02", "mribrec02",
 "abcd_mrfindings01", "mriqc02", "mriqcp202", "freesqc01"]

# %%
non_deskian_tables = ["abcd_mrirstv02", "dmriqc01", "abcd_mid02", "abcd_sst02", "abcd_mrinback02", "mribrec02",
 "abcd_mrfindings01", "mriqc02", "mriqcp202", "freesqc01"]
deskiab_tbls = [it for it in image_tbls if it not in non_deskian_tables]

# %%
imgtbls = {}
imglbls = []
for itn in deskiab_tbls:
    imgtbl, imglbl = load_abcd_table(abcd_table_path +itn + '.txt')
    imglbl['source_file'] = itn
    imgtbls[itn] = imgtbl
    imglbls.append(imglbl)

# %%
imglbls = pd.concat(imglbls, ignore_index=True)

# %%
pd.unique(imgtbl.columns[imgtbl.columns.str.contains('\.')].str.split('_').str[0])
# Out:
# array(['tfmri'], dtype=object)

# %%
# get the modality
modalities = pd.unique(imgtbl.columns[imgtbl.columns.str.contains('\.')].str.split('_').str[0])
assert len(modalities) == 1
modality = modalities[0]

# %%
imglbls['dat'] = imglbls.name.apply(lambda x: len(x.split('.'))>2)

# %%
atlas_guess = imglbls.name[imglbls.name.str.contains('\.') & imglbls.dat].str.split('_').str[-2].unique()
atlas_guess
# Out:
# array(['cort.desikan', 'cort.fuzzy2', 'cort.fuzzy4', 'cort.fuzzy12',
#        'subcort.aseg', 'fiber.at'], dtype=object)

# %%
# those look like reasonable potebtial atlasses
# we'll assert that list to make sure we catch any future changes

assert (atlas_guess == np.array(['cort.desikan', 'cort.fuzzy2', 'cort.fuzzy4', 'cort.fuzzy12', 'subcort.aseg', 'fiber.at'])).all()
for atlas in atlas_guess:
    imglbls.loc[imglbls.name.str.contains(atlas), 'atlas'] = atlas

# %%
imglbls['roi'] = imglbls.loc[pd.notnull(imglbls.atlas), :].apply(lambda x: x['name'].split(x.atlas + '_')[-1], axis=1)

# %%
common_search = (imglbls.groupby('name')[['source_file']]
                  .nunique()
                  .sort_values('source_file', ascending=False)
                  .reset_index()
             )
common_search
# Out:
#                                                                                             name  \
# 0                                                                                 src_subject_id
# 1                                                                            promoted_subjectkey
# 2                                                                                         gender
# 3                                                                                     dataset_id
# 4                                                                               collection_title
# 5                                                                                     subjectkey
# 6                                                                                  interview_age
# 7                                                                                 interview_date
# 8                                                                                  collection_id
# 9                                                                              study_cohort_name
# 10                                                                                     eventname
# 11                            tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_fusiform.lh
# 12                         tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_frontalpole.rh
# 13                         tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_frontalpole.lh
# 14                          tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_entorhinal.rh
# 15                          tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_entorhinal.lh
# 16                              tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_cuneus.rh
# 17                              tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_cuneus.lh
# 18                            tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_fusiform.rh
# 19                    tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_inferiorparietal.lh
# 20                    tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_inferiorparietal.rh
# 21                    tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_inferiortemporal.lh
# 22                    tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_inferiortemporal.rh
# 23                              tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_insula.lh
# 24                              tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_insula.rh
# 25                                                                              abcd_dti_p101_id
# 26                 tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_caudalmiddlefrontal.lh
# 27                    tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_isthmuscingulate.lh
# 28                     tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_parsopercularis.rh
# 29                     tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_parsopercularis.lh
# 30                     tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_parahippocampal.rh
# 31                     tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_parahippocampal.lh
# 32                         tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_paracentral.rh
# 33                         tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_paracentral.lh
# 34                      tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_middletemporal.rh
# 35                      tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_middletemporal.lh
# 36                 tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_medialorbitofrontal.rh
# 37                 tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_medialorbitofrontal.lh
# 38                             tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_lingual.rh
# 39                             tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_lingual.lh
# 40                tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_lateralorbitofrontal.rh
# 41                tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_lateralorbitofrontal.lh
# 42                    tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_lateraloccipital.rh
# 43                    tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_lateraloccipital.lh
# 44                    tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_isthmuscingulate.rh
# 45                 tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_caudalmiddlefrontal.rh
# 46                                  tfmri_nback_run1_face.vs.place_sem_subcort.aseg_ventraldc.rh
# 47             tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_caudalanteriorcingulate.rh
# 48                                    tfmri_nback_run1_face.vs.place_sem_subcort.aseg_caudate.lh
# 49                      tfmri_nback_run1_face.vs.place_sem_subcort.aseg_cerebral.white.matter.lh
# 50                    tfmri_nback_run1_face.vs.place_sem_subcort.aseg_cerebellum.white.matter.rh
# 51                    tfmri_nback_run1_face.vs.place_sem_subcort.aseg_cerebellum.white.matter.lh
# 52                          tfmri_nback_run1_face.vs.place_sem_subcort.aseg_cerebellum.cortex.rh
# 53                          tfmri_nback_run1_face.vs.place_sem_subcort.aseg_cerebellum.cortex.lh
# 54                                    tfmri_nback_run1_face.vs.place_sem_subcort.aseg_caudate.rh
# 55                                    tfmri_nback_run1_face.vs.place_sem_subcort.aseg_brain.stem
# 56                                           tfmri_nback_run1_face.vs.place_sem_subcort.aseg_csf
# 57                                   tfmri_nback_run1_face.vs.place_sem_subcort.aseg_amygdala.rh
# 58                                   tfmri_nback_run1_face.vs.place_sem_subcort.aseg_amygdala.lh
# 59                             tfmri_nback_run1_face.vs.place_sem_subcort.aseg_accumbens.area.rh
# 60                             tfmri_nback_run1_face.vs.place_sem_subcort.aseg_accumbens.area.lh
# 61                                 tfmri_nback_run1_face.vs.place_sem_subcort.aseg_4th.ventricle
# 62                                 tfmri_nback_run1_face.vs.place_sem_subcort.aseg_3rd.ventricle
# 63                      tfmri_nback_run1_face.vs.place_sem_subcort.aseg_cerebral.white.matter.rh
# 64                                tfmri_nback_run1_face.vs.place_sem_subcort.aseg_hippocampus.lh
# 65             tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_caudalanteriorcingulate.lh
# 66                                    tfmri_nback_run1_face.vs.place_sem_subcort.aseg_putamen.rh
# 67                            tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_bankssts.rh
# 68                            tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_bankssts.lh
# 69                       tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_parsorbitalis.rh
# 70                                  tfmri_nback_run1_face.vs.place_sem_subcort.aseg_ventraldc.lh
# 71                            tfmri_nback_run1_face.vs.place_sem_subcort.aseg_thalamus.proper.rh
# 72                            tfmri_nback_run1_face.vs.place_sem_subcort.aseg_thalamus.proper.lh
# 73                                    tfmri_nback_run1_face.vs.place_sem_subcort.aseg_putamen.lh
# 74                                tfmri_nback_run1_face.vs.place_sem_subcort.aseg_hippocampus.rh
# 75                                   tfmri_nback_run1_face.vs.place_sem_subcort.aseg_pallidum.rh
# 76                                   tfmri_nback_run1_face.vs.place_sem_subcort.aseg_pallidum.lh
# 77                          tfmri_nback_run1_face.vs.place_sem_subcort.aseg_lateral.ventricle.rh
# 78                          tfmri_nback_run1_face.vs.place_sem_subcort.aseg_lateral.ventricle.lh
# 79                               tfmri_nback_run1_face.vs.place_sem_subcort.aseg_inf.lat.vent.rh
# 80                               tfmri_nback_run1_face.vs.place_sem_subcort.aseg_inf.lat.vent.lh
# 81                       tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_parsorbitalis.lh
# 82                    tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_parstriangularis.rh
# 83                    tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_parstriangularis.lh
# 84                   tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_lateral.ventricle.rh
# 85                           tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_ventraldc.lh
# 86                     tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_thalamus.proper.rh
# 87                     tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_thalamus.proper.lh
# 88                             tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_putamen.rh
# 89                             tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_putamen.lh
# 90                            tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_pallidum.rh
# 91                            tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_pallidum.lh
# 92                   tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_lateral.ventricle.lh
# 93                             tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_bankssts.lh
# 94                        tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_inf.lat.vent.rh
# 95                        tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_inf.lat.vent.lh
# 96                         tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_hippocampus.rh
# 97                         tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_hippocampus.lh
# 98                                    tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_csf
# 99               tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_cerebral.white.matter.rh
# 100              tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_cerebral.white.matter.lh
# 101                          tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_ventraldc.rh
# 102                            tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_bankssts.rh
# 103                        tfmri_nback_run1_face.vs.place_sem_cort.desikan_transversetemporal.lh
# 104                         tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_frontalpole.rh
# 105                              tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_insula.lh
# 106                    tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_inferiortemporal.rh
# 107                    tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_inferiortemporal.lh
# 108                    tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_inferiorparietal.rh
# 109                    tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_inferiorparietal.lh
# 110                            tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_fusiform.rh
# 111                            tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_fusiform.lh
# 112                         tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_frontalpole.lh
# 113             tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_caudalanteriorcingulate.lh
# 114                          tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_entorhinal.rh
# 115                          tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_entorhinal.lh
# 116                              tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_cuneus.rh
# 117                              tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_cuneus.lh
# 118                 tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_caudalmiddlefrontal.rh
# 119                 tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_caudalmiddlefrontal.lh
# 120             tfmri_nback_run1_negface.vs.neutface_sem_cort.desikan_caudalanteriorcingulate.rh
# 121            tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_cerebellum.white.matter.rh
# 122            tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_cerebellum.white.matter.lh
# 123                  tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_cerebellum.cortex.rh
# 124                          tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_precuneus.lh
# 125                    tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_superiorfrontal.rh
# 126                    tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_superiorfrontal.lh
# 127               tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_rostralmiddlefrontal.rh
# 128               tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_rostralmiddlefrontal.lh
# 129           tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_rostralanteriorcingulate.rh
# 130           tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_rostralanteriorcingulate.lh
# 131                          tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_precuneus.rh
# 132                         tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_precentral.rh
# 133                  tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_cerebellum.cortex.lh
# 134                         tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_precentral.lh
# 135                 tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_posteriorcingulate.rh
# 136                 tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_posteriorcingulate.lh
# 137                        tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_postcentral.rh
# 138                        tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_postcentral.lh
# 139                      tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_pericalcarine.rh
# 140                      tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_pericalcarine.lh
# 141                   tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_superiorparietal.lh
# 142                   tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_superiorparietal.rh
# 143                   tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_superiortemporal.lh
# 144                   tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_superiortemporal.rh
# 145                            tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_caudate.rh
# 146                            tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_caudate.lh
# 147                            tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_brain.stem
# 148                           tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_amygdala.rh
# 149                           tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_amygdala.lh
# 150                     tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_accumbens.area.rh
# 151                     tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_accumbens.area.lh
# 152                         tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_4th.ventricle
# 153                         tfmri_nback_run1_negface.vs.neutface_beta_subcort.aseg_3rd.ventricle
# 154                 tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_transversetemporal.rh
# 155                 tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_transversetemporal.lh
# 156                       tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_temporalpole.rh
# 157                       tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_temporalpole.lh
# 158                      tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_supramarginal.rh
# 159                      tfmri_nback_run1_negface.vs.neutface_beta_cort.desikan_supramarginal.lh
# 160                        tfmri_nback_run1_face.vs.place_sem_cort.desikan_transversetemporal.rh
# 161                          tfmri_nback_run1_face.vs.place_sem_cort.desikan_superiortemporal.lh
# 162                              tfmri_nback_run1_face.vs.place_sem_cort.desikan_temporalpole.rh
# 163                               tfmri_nback_run1_face.vs.place_beta_subcort.aseg_4th.ventricle
# 164                       tfmri_nback_run1_face.vs.place_beta_cort.desikan_transversetemporal.rh
# 165                       tfmri_nback_run1_face.vs.place_beta_cort.desikan_transversetemporal.lh
# 166                             tfmri_nback_run1_face.vs.place_beta_cort.desikan_temporalpole.rh
# 167                             tfmri_nback_run1_face.vs.place_beta_cort.desikan_temporalpole.lh
# 168                            tfmri_nback_run1_face.vs.place_beta_cort.desikan_supramarginal.rh
# 169                            tfmri_nback_run1_face.vs.place_beta_cort.desikan_supramarginal.lh
# 170                         tfmri_nback_run1_face.vs.place_beta_cort.desikan_superiortemporal.rh
# 171                         tfmri_nback_run1_face.vs.place_beta_cort.desikan_superiortemporal.lh
# 172                         tfmri_nback_run1_face.vs.place_beta_cort.desikan_superiorparietal.rh
# 173                         tfmri_nback_run1_face.vs.place_beta_cort.desikan_superiorparietal.lh
# 174                          tfmri_nback_run1_face.vs.place_beta_cort.desikan_superiorfrontal.rh
# 175                          tfmri_nback_run1_face.vs.place_beta_cort.desikan_superiorfrontal.lh
# 176                     tfmri_nback_run1_face.vs.place_beta_cort.desikan_rostralmiddlefrontal.rh
# 177                     tfmri_nback_run1_face.vs.place_beta_cort.desikan_rostralmiddlefrontal.lh
# 178                 tfmri_nback_run1_face.vs.place_beta_cort.desikan_rostralanteriorcingulate.rh
# 179                               tfmri_nback_run1_face.vs.place_beta_subcort.aseg_3rd.ventricle
# 180                           tfmri_nback_run1_face.vs.place_beta_subcort.aseg_accumbens.area.lh
# 181                                tfmri_nback_run1_face.vs.place_beta_cort.desikan_precuneus.rh
# 182                           tfmri_nback_run1_face.vs.place_beta_subcort.aseg_accumbens.area.rh
# 183                             tfmri_nback_run1_face.vs.place_beta_subcort.aseg_inf.lat.vent.lh
# 184                              tfmri_nback_run1_face.vs.place_beta_subcort.aseg_hippocampus.rh
# 185                              tfmri_nback_run1_face.vs.place_beta_subcort.aseg_hippocampus.lh
# 186                                         tfmri_nback_run1_face.vs.place_beta_subcort.aseg_csf
# 187                    tfmri_nback_run1_face.vs.place_beta_subcort.aseg_cerebral.white.matter.rh
# 188                    tfmri_nback_run1_face.vs.place_beta_subcort.aseg_cerebral.white.matter.lh
# 189                  tfmri_nback_run1_face.vs.place_beta_subcort.aseg_cerebellum.white.matter.rh
# 190                  tfmri_nback_run1_face.vs.place_beta_subcort.aseg_cerebellum.white.matter.lh
# 191                        tfmri_nback_run1_face.vs.place_beta_subcort.aseg_cerebellum.cortex.rh
# 192                        tfmri_nback_run1_face.vs.place_beta_subcort.aseg_cerebellum.cortex.lh
# 193                                  tfmri_nback_run1_face.vs.place_beta_subcort.aseg_caudate.rh
# 194                                  tfmri_nback_run1_face.vs.place_beta_subcort.aseg_caudate.lh
# 195                                  tfmri_nback_run1_face.vs.place_beta_subcort.aseg_brain.stem
# 196                                 tfmri_nback_run1_face.vs.place_beta_subcort.aseg_amygdala.rh
# 197                                 tfmri_nback_run1_face.vs.place_beta_subcort.aseg_amygdala.lh
# 198                 tfmri_nback_run1_face.vs.place_beta_cort.desikan_rostralanteriorcingulate.lh
# 199                                tfmri_nback_run1_face.vs.place_beta_cort.desikan_precuneus.lh
# 200                              tfmri_nback_run1_face.vs.place_sem_cort.desikan_temporalpole.lh
# 201                           tfmri_nback_run1_face.vs.place_beta_cort.desikan_middletemporal.rh
# 202                      tfmri_nback_run1_face.vs.place_beta_cort.desikan_medialorbitofrontal.rh
# 203                      tfmri_nback_run1_face.vs.place_beta_cort.desikan_medialorbitofrontal.lh
# 204                                  tfmri_nback_run1_face.vs.place_beta_cort.desikan_lingual.rh
# 205                                  tfmri_nback_run1_face.vs.place_beta_cort.desikan_lingual.lh
# 206                     tfmri_nback_run1_face.vs.place_beta_cort.desikan_lateralorbitofrontal.rh
# 207                     tfmri_nback_run1_face.vs.place_beta_cort.desikan_lateralorbitofrontal.lh
# 208                         tfmri_nback_run1_face.vs.place_beta_cort.desikan_lateraloccipital.rh
# 209                         tfmri_nback_run1_face.vs.place_beta_cort.desikan_lateraloccipital.lh
# 210                         tfmri_nback_run1_face.vs.place_beta_cort.desikan_isthmuscingulate.rh
# 211                         tfmri_nback_run1_face.vs.place_beta_cort.desikan_isthmuscingulate.lh
# 212                                   tfmri_nback_run1_face.vs.place_beta_cort.desikan_insula.rh
# 213                                   tfmri_nback_run1_face.vs.place_beta_cort.desikan_insula.lh
# 214                         tfmri_nback_run1_face.vs.place_beta_cort.desikan_inferiortemporal.rh
# 215                         tfmri_nback_run1_face.vs.place_beta_cort.desikan_inferiortemporal.lh
# 216                         tfmri_nback_run1_face.vs.place_beta_cort.desikan_inferiorparietal.rh
# 217                           tfmri_nback_run1_face.vs.place_beta_cort.desikan_middletemporal.lh
# 218                              tfmri_nback_run1_face.vs.place_beta_cort.desikan_paracentral.lh
# 219                               tfmri_nback_run1_face.vs.place_beta_cort.desikan_precentral.rh
# 220                              tfmri_nback_run1_face.vs.place_beta_cort.desikan_paracentral.rh
# 221                               tfmri_nback_run1_face.vs.place_beta_cort.desikan_precentral.lh
# 222                       tfmri_nback_run1_face.vs.place_beta_cort.desikan_posteriorcingulate.rh
# 223                       tfmri_nback_run1_face.vs.place_beta_cort.desikan_posteriorcingulate.lh
# 224                              tfmri_nback_run1_face.vs.place_beta_cort.desikan_postcentral.rh
# 225                              tfmri_nback_run1_face.vs.place_beta_cort.desikan_postcentral.lh
# 226                            tfmri_nback_run1_face.vs.place_beta_cort.desikan_pericalcarine.rh
# 227                            tfmri_nback_run1_face.vs.place_beta_cort.desikan_pericalcarine.lh
# 228                         tfmri_nback_run1_face.vs.place_beta_cort.desikan_parstriangularis.rh
# 229                         tfmri_nback_run1_face.vs.place_beta_cort.desikan_parstriangularis.lh
# 230                            tfmri_nback_run1_face.vs.place_beta_cort.desikan_parsorbitalis.rh
# 231                            tfmri_nback_run1_face.vs.place_beta_cort.desikan_parsorbitalis.lh
# 232                          tfmri_nback_run1_face.vs.place_beta_cort.desikan_parsopercularis.rh
# 233                          tfmri_nback_run1_face.vs.place_beta_cort.desikan_parsopercularis.lh
# 234                          tfmri_nback_run1_face.vs.place_beta_cort.desikan_parahippocampal.rh
# 235                          tfmri_nback_run1_face.vs.place_beta_cort.desikan_parahippocampal.lh
# 236                             tfmri_nback_run1_face.vs.place_beta_subcort.aseg_inf.lat.vent.rh
# 237                        tfmri_nback_run1_face.vs.place_beta_subcort.aseg_lateral.ventricle.lh
# 238                        tfmri_nback_run1_face.vs.place_beta_subcort.aseg_lateral.ventricle.rh
# 239                        tfmri_nback_run1_face.vs.place_sem_cort.desikan_posteriorcingulate.lh
# 240                               tfmri_nback_run1_face.vs.place_sem_cort.desikan_postcentral.lh
# 241                             tfmri_nback_run1_face.vs.place_sem_cort.desikan_pericalcarine.rh
# 242                             tfmri_nback_run1_face.vs.place_sem_cort.desikan_pericalcarine.lh
# 243                          tfmri_nback_run1_face.vs.place_sem_cort.desikan_parstriangularis.rh
# 244                          tfmri_nback_run1_face.vs.place_sem_cort.desikan_parstriangularis.lh
# 245                             tfmri_nback_run1_face.vs.place_sem_cort.desikan_parsorbitalis.rh
# 246                             tfmri_nback_run1_face.vs.place_sem_cort.desikan_parsorbitalis.lh
# 247                           tfmri_nback_run1_face.vs.place_sem_cort.desikan_parsopercularis.rh
# 248                           tfmri_nback_run1_face.vs.place_sem_cort.desikan_parsopercularis.lh
# 249                           tfmri_nback_run1_face.vs.place_sem_cort.desikan_parahippocampal.rh
# ...                                                                                          ...
# 19434        tfmri_mid_run1_antic.large.vs.small.loss_beta_subcort.aseg_cerebral.white.matter.lh
# 19435                             tfmri_mid_run1_antic.large.vs.small.loss_beta_subcort.aseg_csf
# 19436       tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_caudalanteriorcingulate.lh
# 19437                  tfmri_mid_run1_antic.large.vs.small.loss_beta_subcort.aseg_hippocampus.lh
# 19438                      tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_bankssts.rh
# 19439                      tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_bankssts.lh
# 19440                    tfmri_mid_run1_antic.large.vs.small.loss_beta_subcort.aseg_ventraldc.rh
# 19441                    tfmri_mid_run1_antic.large.vs.small.loss_beta_subcort.aseg_ventraldc.lh
# 19442              tfmri_mid_run1_antic.large.vs.small.loss_beta_subcort.aseg_thalamus.proper.rh
# 19443              tfmri_mid_run1_antic.large.vs.small.loss_beta_subcort.aseg_thalamus.proper.lh
# 19444                      tfmri_mid_run1_antic.large.vs.small.loss_beta_subcort.aseg_putamen.rh
# 19445                      tfmri_mid_run1_antic.large.vs.small.loss_beta_subcort.aseg_putamen.lh
# 19446                     tfmri_mid_run1_antic.large.vs.small.loss_beta_subcort.aseg_pallidum.rh
# 19447                     tfmri_mid_run1_antic.large.vs.small.loss_beta_subcort.aseg_pallidum.lh
# 19448            tfmri_mid_run1_antic.large.vs.small.loss_beta_subcort.aseg_lateral.ventricle.rh
# 19449            tfmri_mid_run1_antic.large.vs.small.loss_beta_subcort.aseg_lateral.ventricle.lh
# 19450                 tfmri_mid_run1_antic.large.vs.small.loss_beta_subcort.aseg_inf.lat.vent.rh
# 19451                 tfmri_mid_run1_antic.large.vs.small.loss_beta_subcort.aseg_inf.lat.vent.lh
# 19452                  tfmri_mid_run1_antic.large.vs.small.loss_beta_subcort.aseg_hippocampus.rh
# 19453              tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_parstriangularis.rh
# 19454                 tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_pericalcarine.rh
# 19455               tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_frontalpole.lh
# 19456                      tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_pallidum.rh
# 19457                   tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_bankssts.lh
# 19458                     tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_ventraldc.rh
# 19459                     tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_ventraldc.lh
# 19460               tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_thalamus.proper.rh
# 19461               tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_thalamus.proper.lh
# 19462                       tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_putamen.rh
# 19463                       tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_putamen.lh
# 19464                      tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_pallidum.lh
# 19465                   tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_postcentral.lh
# 19466             tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_lateral.ventricle.rh
# 19467             tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_lateral.ventricle.lh
# 19468                  tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_inf.lat.vent.rh
# 19469                  tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_inf.lat.vent.lh
# 19470                   tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_hippocampus.rh
# 19471                   tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_hippocampus.lh
# 19472                              tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_csf
# 19473                   tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_bankssts.rh
# 19474    tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_caudalanteriorcingulate.lh
# 19475    tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_caudalanteriorcingulate.rh
# 19476        tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_caudalmiddlefrontal.lh
# 19477                     tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_insula.rh
# 19478                     tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_insula.lh
# 19479           tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_inferiortemporal.rh
# 19480           tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_inferiortemporal.lh
# 19481           tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_inferiorparietal.rh
# 19482           tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_inferiorparietal.lh
# 19483                   tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_fusiform.rh
# 19484                   tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_fusiform.lh
# 19485                tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_frontalpole.rh
# 19486                tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_frontalpole.lh
# 19487                 tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_entorhinal.rh
# 19488                 tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_entorhinal.lh
# 19489                     tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_cuneus.rh
# 19490                     tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_cuneus.lh
# 19491        tfmri_mid_run1_antic.large.vs.small.reward_beta_cort.desikan_caudalmiddlefrontal.rh
# 19492         tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_cerebral.white.matter.rh
# 19493         tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_cerebral.white.matter.lh
# 19494       tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_cerebellum.white.matter.rh
# 19495              tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_superiortemporal.rh
# 19496              tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_superiorparietal.rh
# 19497              tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_superiorparietal.lh
# 19498               tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_superiorfrontal.rh
# 19499               tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_superiorfrontal.lh
# 19500          tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_rostralmiddlefrontal.rh
# 19501          tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_rostralmiddlefrontal.lh
# 19502      tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_rostralanteriorcingulate.rh
# 19503      tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_rostralanteriorcingulate.lh
# 19504                     tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_precuneus.rh
# 19505                     tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_precuneus.lh
# 19506                    tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_precentral.rh
# 19507                    tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_precentral.lh
# 19508            tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_posteriorcingulate.rh
# 19509            tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_posteriorcingulate.lh
# 19510                   tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_postcentral.rh
# 19511              tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_superiortemporal.lh
# 19512                 tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_supramarginal.lh
# 19513       tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_cerebellum.white.matter.lh
# 19514                 tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_supramarginal.rh
# 19515             tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_cerebellum.cortex.rh
# 19516             tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_cerebellum.cortex.lh
# 19517                       tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_caudate.rh
# 19518                       tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_caudate.lh
# 19519                       tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_brain.stem
# 19520                      tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_amygdala.rh
# 19521                      tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_amygdala.lh
# 19522                tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_accumbens.area.rh
# 19523                tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_accumbens.area.lh
# 19524                    tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_4th.ventricle
# 19525                    tfmri_mid_run1_antic.large.vs.small.loss_sem_subcort.aseg_3rd.ventricle
# 19526            tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_transversetemporal.rh
# 19527            tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_transversetemporal.lh
# 19528                  tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_temporalpole.rh
# 19529                  tfmri_mid_run1_antic.large.vs.small.loss_sem_cort.desikan_temporalpole.lh
# 19530                 tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_temporalpole.rh
# 19531                 tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_temporalpole.lh
# 19532                tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_supramarginal.rh
# 19533           tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_superiorfrontal.rh
# 19534              tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_temporalpole.lh
# 19535             tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_supramarginal.rh
# 19536             tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_supramarginal.lh
# 19537          tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_superiortemporal.rh
# 19538          tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_superiortemporal.lh
# 19539          tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_superiorparietal.rh
# 19540          tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_superiorparietal.lh
# 19541           tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_superiorfrontal.lh
# 19542                tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_supramarginal.lh
# 19543      tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_rostralmiddlefrontal.rh
# 19544      tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_rostralmiddlefrontal.lh
# 19545  tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_rostralanteriorcingulate.rh
# 19546  tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_rostralanteriorcingulate.lh
# 19547                 tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_precuneus.rh
# 19548                 tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_precuneus.lh
# 19549                tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_precentral.rh
# 19550              tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_temporalpole.rh
# 19551        tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_transversetemporal.lh
# 19552        tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_transversetemporal.rh
# 19553                tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_3rd.ventricle
# 19554                          tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_csf
# 19555     tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_cerebral.white.matter.rh
# 19556     tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_cerebral.white.matter.lh
# 19557   tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_cerebellum.white.matter.rh
# 19558   tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_cerebellum.white.matter.lh
# 19559         tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_cerebellum.cortex.rh
# 19560         tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_cerebellum.cortex.lh
# 19561                   tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_caudate.rh
# 19562                   tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_caudate.lh
# 19563                   tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_brain.stem
# 19564                  tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_amygdala.rh
# 19565                  tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_amygdala.lh
# 19566            tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_accumbens.area.rh
# 19567            tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_accumbens.area.lh
# 19568                tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_4th.ventricle
# 19569                tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_precentral.lh
# 19570        tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_posteriorcingulate.rh
# 19571        tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_posteriorcingulate.lh
# 19572                   tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_lingual.rh
# 19573      tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_lateralorbitofrontal.rh
# 19574      tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_lateralorbitofrontal.lh
# 19575          tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_lateraloccipital.rh
# 19576          tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_lateraloccipital.lh
# 19577          tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_isthmuscingulate.rh
# 19578          tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_isthmuscingulate.lh
# 19579                    tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_insula.rh
# 19580                    tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_insula.lh
# 19581          tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_inferiortemporal.rh
# 19582          tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_inferiortemporal.lh
# 19583          tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_inferiorparietal.rh
# 19584          tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_inferiorparietal.lh
# 19585                  tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_fusiform.rh
# 19586                  tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_fusiform.lh
# 19587               tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_frontalpole.rh
# 19588                   tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_lingual.lh
# 19589       tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_medialorbitofrontal.lh
# 19590               tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_postcentral.rh
# 19591       tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_medialorbitofrontal.rh
# 19592               tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_postcentral.lh
# 19593             tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_pericalcarine.rh
# 19594             tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_pericalcarine.lh
# 19595          tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_parstriangularis.rh
# 19596          tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_parstriangularis.lh
# 19597             tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_parsorbitalis.rh
# 19598             tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_parsorbitalis.lh
# 19599           tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_parsopercularis.rh
# 19600           tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_parsopercularis.lh
# 19601           tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_parahippocampal.rh
# 19602           tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_parahippocampal.lh
# 19603               tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_paracentral.rh
# 19604               tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_paracentral.lh
# 19605            tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_middletemporal.rh
# 19606            tfmri_mid_run1_antic.large.reward.vs.neutral_sem_cort.desikan_middletemporal.lh
# 19607               tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_hippocampus.lh
# 19608               tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_hippocampus.rh
# 19609              tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_inf.lat.vent.lh
# 19610                  tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_postcentral.lh
# 19611                tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_pericalcarine.lh
# 19612             tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_parstriangularis.rh
# 19613             tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_parstriangularis.lh
# 19614                tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_parsorbitalis.rh
# 19615                tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_parsorbitalis.lh
# 19616              tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_parsopercularis.rh
# 19617              tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_parsopercularis.lh
# 19618              tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_parahippocampal.rh
# 19619              tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_parahippocampal.lh
# 19620                  tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_paracentral.rh
# 19621                  tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_paracentral.lh
# 19622               tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_middletemporal.rh
# 19623               tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_middletemporal.lh
# 19624          tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_medialorbitofrontal.rh
# 19625          tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_medialorbitofrontal.lh
# 19626                tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_pericalcarine.rh
# 19627                  tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_postcentral.rh
# 19628                      tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_lingual.lh
# 19629           tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_posteriorcingulate.lh
# 19630             tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_superiortemporal.rh
# 19631             tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_superiortemporal.lh
# 19632             tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_superiorparietal.rh
# 19633             tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_superiorparietal.lh
# 19634              tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_superiorfrontal.rh
# 19635              tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_superiorfrontal.lh
# 19636         tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_rostralmiddlefrontal.rh
# 19637         tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_rostralmiddlefrontal.lh
# 19638     tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_rostralanteriorcingulate.rh
# 19639     tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_rostralanteriorcingulate.lh
# 19640                    tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_precuneus.rh
# 19641                    tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_precuneus.lh
# 19642                   tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_precentral.rh
# 19643                   tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_precentral.lh
# 19644           tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_posteriorcingulate.rh
# 19645                      tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_lingual.rh
# 19646         tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_lateralorbitofrontal.rh
# 19647              tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_inf.lat.vent.rh
# 19648                       tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_cuneus.lh
# 19649          tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_caudalmiddlefrontal.lh
# 19650      tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_caudalanteriorcingulate.rh
# 19651      tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_caudalanteriorcingulate.lh
# 19652                     tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_bankssts.rh
# 19653                     tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_bankssts.lh
# 19654                 tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_ventraldc.rh
# 19655                 tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_ventraldc.lh
# 19656           tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_thalamus.proper.rh
# 19657           tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_thalamus.proper.lh
# 19658                   tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_putamen.rh
# 19659                   tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_putamen.lh
# 19660                  tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_pallidum.rh
# 19661                  tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_pallidum.lh
# 19662         tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_lateral.ventricle.rh
# 19663         tfmri_mid_run1_antic.large.reward.vs.neutral_sem_subcort.aseg_lateral.ventricle.lh
# 19664          tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_caudalmiddlefrontal.rh
# 19665                       tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_cuneus.rh
# 19666         tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_lateralorbitofrontal.lh
# 19667                   tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_entorhinal.lh
# 19668             tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_lateraloccipital.rh
# 19669             tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_lateraloccipital.lh
# 19670             tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_isthmuscingulate.rh
# 19671             tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_isthmuscingulate.lh
# 19672                       tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_insula.rh
# 19673                       tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_insula.lh
# 19674             tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_inferiortemporal.rh
# 19675             tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_inferiortemporal.lh
# 19676             tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_inferiorparietal.rh
# 19677             tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_inferiorparietal.lh
# 19678                     tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_fusiform.rh
# 19679                     tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_fusiform.lh
# 19680                  tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_frontalpole.rh
# 19681                  tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_frontalpole.lh
# 19682                   tfmri_mid_run1_antic.large.vs.small.loss_beta_cort.desikan_entorhinal.rh
# 19683                                                                      tfmrinbr2pscdkracgerh
#
#        source_file
# 0               30
# 1               30
# 2               30
# 3               30
# 4               30
# 5               30
# 6               30
# 7               30
# 8               30
# 9               30
# 10              23
# 11               1
# 12               1
# 13               1
# 14               1
# 15               1
# 16               1
# 17               1
# 18               1
# 19               1
# 20               1
# 21               1
# 22               1
# 23               1
# 24               1
# 25               1
# 26               1
# 27               1
# 28               1
# 29               1
# 30               1
# 31               1
# 32               1
# 33               1
# 34               1
# 35               1
# 36               1
# 37               1
# 38               1
# 39               1
# 40               1
# 41               1
# 42               1
# 43               1
# 44               1
# 45               1
# 46               1
# 47               1
# 48               1
# 49               1
# 50               1
# 51               1
# 52               1
# 53               1
# 54               1
# 55               1
# 56               1
# 57               1
# 58               1
# 59               1
# 60               1
# 61               1
# 62               1
# 63               1
# 64               1
# 65               1
# 66               1
# 67               1
# 68               1
# 69               1
# 70               1
# 71               1
# 72               1
# 73               1
# 74               1
# 75               1
# 76               1
# 77               1
# 78               1
# 79               1
# 80               1
# 81               1
# 82               1
# 83               1
# 84               1
# 85               1
# 86               1
# 87               1
# 88               1
# 89               1
# 90               1
# 91               1
# 92               1
# 93               1
# 94               1
# 95               1
# 96               1
# 97               1
# 98               1
# 99               1
# 100              1
# 101              1
# 102              1
# 103              1
# 104              1
# 105              1
# 106              1
# 107              1
# 108              1
# 109              1
# 110              1
# 111              1
# 112              1
# 113              1
# 114              1
# 115              1
# 116              1
# 117              1
# 118              1
# 119              1
# 120              1
# 121              1
# 122              1
# 123              1
# 124              1
# 125              1
# 126              1
# 127              1
# 128              1
# 129              1
# 130              1
# 131              1
# 132              1
# 133              1
# 134              1
# 135              1
# 136              1
# 137              1
# 138              1
# 139              1
# 140              1
# 141              1
# 142              1
# 143              1
# 144              1
# 145              1
# 146              1
# 147              1
# 148              1
# 149              1
# 150              1
# 151              1
# 152              1
# 153              1
# 154              1
# 155              1
# 156              1
# 157              1
# 158              1
# 159              1
# 160              1
# 161              1
# 162              1
# 163              1
# 164              1
# 165              1
# 166              1
# 167              1
# 168              1
# 169              1
# 170              1
# 171              1
# 172              1
# 173              1
# 174              1
# 175              1
# 176              1
# 177              1
# 178              1
# 179              1
# 180              1
# 181              1
# 182              1
# 183              1
# 184              1
# 185              1
# 186              1
# 187              1
# 188              1
# 189              1
# 190              1
# 191              1
# 192              1
# 193              1
# 194              1
# 195              1
# 196              1
# 197              1
# 198              1
# 199              1
# 200              1
# 201              1
# 202              1
# 203              1
# 204              1
# 205              1
# 206              1
# 207              1
# 208              1
# 209              1
# 210              1
# 211              1
# 212              1
# 213              1
# 214              1
# 215              1
# 216              1
# 217              1
# 218              1
# 219              1
# 220              1
# 221              1
# 222              1
# 223              1
# 224              1
# 225              1
# 226              1
# 227              1
# 228              1
# 229              1
# 230              1
# 231              1
# 232              1
# 233              1
# 234              1
# 235              1
# 236              1
# 237              1
# 238              1
# 239              1
# 240              1
# 241              1
# 242              1
# 243              1
# 244              1
# 245              1
# 246              1
# 247              1
# 248              1
# 249              1
# ...            ...
# 19434            1
# 19435            1
# 19436            1
# 19437            1
# 19438            1
# 19439            1
# 19440            1
# 19441            1
# 19442            1
# 19443            1
# 19444            1
# 19445            1
# 19446            1
# 19447            1
# 19448            1
# 19449            1
# 19450            1
# 19451            1
# 19452            1
# 19453            1
# 19454            1
# 19455            1
# 19456            1
# 19457            1
# 19458            1
# 19459            1
# 19460            1
# 19461            1
# 19462            1
# 19463            1
# 19464            1
# 19465            1
# 19466            1
# 19467            1
# 19468            1
# 19469            1
# 19470            1
# 19471            1
# 19472            1
# 19473            1
# 19474            1
# 19475            1
# 19476            1
# 19477            1
# 19478            1
# 19479            1
# 19480            1
# 19481            1
# 19482            1
# 19483            1
# 19484            1
# 19485            1
# 19486            1
# 19487            1
# 19488            1
# 19489            1
# 19490            1
# 19491            1
# 19492            1
# 19493            1
# 19494            1
# 19495            1
# 19496            1
# 19497            1
# 19498            1
# 19499            1
# 19500            1
# 19501            1
# 19502            1
# 19503            1
# 19504            1
# 19505            1
# 19506            1
# 19507            1
# 19508            1
# 19509            1
# 19510            1
# 19511            1
# 19512            1
# 19513            1
# 19514            1
# 19515            1
# 19516            1
# 19517            1
# 19518            1
# 19519            1
# 19520            1
# 19521            1
# 19522            1
# 19523            1
# 19524            1
# 19525            1
# 19526            1
# 19527            1
# 19528            1
# 19529            1
# 19530            1
# 19531            1
# 19532            1
# 19533            1
# 19534            1
# 19535            1
# 19536            1
# 19537            1
# 19538            1
# 19539            1
# 19540            1
# 19541            1
# 19542            1
# 19543            1
# 19544            1
# 19545            1
# 19546            1
# 19547            1
# 19548            1
# 19549            1
# 19550            1
# 19551            1
# 19552            1
# 19553            1
# 19554            1
# 19555            1
# 19556            1
# 19557            1
# 19558            1
# 19559            1
# 19560            1
# 19561            1
# 19562            1
# 19563            1
# 19564            1
# 19565            1
# 19566            1
# 19567            1
# 19568            1
# 19569            1
# 19570            1
# 19571            1
# 19572            1
# 19573            1
# 19574            1
# 19575            1
# 19576            1
# 19577            1
# 19578            1
# 19579            1
# 19580            1
# 19581            1
# 19582            1
# 19583            1
# 19584            1
# 19585            1
# 19586            1
# 19587            1
# 19588            1
# 19589            1
# 19590            1
# 19591            1
# 19592            1
# 19593            1
# 19594            1
# 19595            1
# 19596            1
# 19597            1
# 19598            1
# 19599            1
# 19600            1
# 19601            1
# 19602            1
# 19603            1
# 19604            1
# 19605            1
# 19606            1
# 19607            1
# 19608            1
# 19609            1
# 19610            1
# 19611            1
# 19612            1
# 19613            1
# 19614            1
# 19615            1
# 19616            1
# 19617            1
# 19618            1
# 19619            1
# 19620            1
# 19621            1
# 19622            1
# 19623            1
# 19624            1
# 19625            1
# 19626            1
# 19627            1
# 19628            1
# 19629            1
# 19630            1
# 19631            1
# 19632            1
# 19633            1
# 19634            1
# 19635            1
# 19636            1
# 19637            1
# 19638            1
# 19639            1
# 19640            1
# 19641            1
# 19642            1
# 19643            1
# 19644            1
# 19645            1
# 19646            1
# 19647            1
# 19648            1
# 19649            1
# 19650            1
# 19651            1
# 19652            1
# 19653            1
# 19654            1
# 19655            1
# 19656            1
# 19657            1
# 19658            1
# 19659            1
# 19660            1
# 19661            1
# 19662            1
# 19663            1
# 19664            1
# 19665            1
# 19666            1
# 19667            1
# 19668            1
# 19669            1
# 19670            1
# 19671            1
# 19672            1
# 19673            1
# 19674            1
# 19675            1
# 19676            1
# 19677            1
# 19678            1
# 19679            1
# 19680            1
# 19681            1
# 19682            1
# 19683            1
#
# [19684 rows x 2 columns]

# %%
common_cols = common_search.query('source_file >= 23').name.values

# %%
imglbls['common']= imglbls.name.isin(common_cols)

# %%
imglbls['dat'] = pd.notnull(imglbls.roi)

# %%
imglbls['other'] = imglbls.query('~dat & ~common').name.str.split('_').str[-1]

# %%
imglbls.other.unique()
# Out:
# array([nan, 'id', 'visitid', 'rrmdfrlh', 'mean.motion', 'mean.trans',
#        'mean.rot', 'rncntelh', 'tr', 'numtrs', 'dof', 'nvols',
#        'subthresh.nvols', 'max.motion', 'max.trans', 'max.rot',
#        'cdmdftrh', 'clmdfrh', '465', '473', 'tfmrinbr2pscdkracgerh'],
#       dtype=object)

# %%
# Some of those look ok, others, not so much
tbl_meta = ['id', 'visitid', 'mean.motion', 'mean.trans',
            'mean.rot', 'tr', 'numtrs', 'dof', 'nvols',
            'subthresh.nvols', 'max.motion', 'max.trans', 'max.rot']
#tbl_meta = ['_' + tm for tm in tbl_meta]

# %% [markdown]
# ### Figure out names to clean up

# %%
name_reform = {
    'tfmri_nback_all_465': 'tfmri_nback_all_place_beta_cort.desikan_rostralanteriorcingulate.rh',
    'tfmri_nback_r1sem_465': 'tfmri_nback_run1_place_sem_cort.desikan_rostralanteriorcingulate.rh',
    'tfmrinbackallsem_473': 'tfmri_nback_all_place_sem_cort.desikan_transversetemporal.rh',
    'tfmri_mr1_asrvn_bcdk_cdmdftrh': 'tfmri_mid_run1_antic.small.reward.vs.neutral_beta_cort.desikan_caudalmiddlefrontal.rh',
    'tfmri_mr2_asrvn_bcdk_clmdfrh': 'tfmri_mid_run2_antic.small.reward.vs.neutral_beta_cort.desikan_caudalmiddlefrontal.rh',
    'dmri_dtimdgm_cdsn_rncntelh': 'dmri_dti.md.gm_cort.desikan_rostralanteriorcingulate.lh',
    'smri_t1wcnt_cdk_rrmdfrlh': 'smri_t1w.contrast_cort.desikan_rostralmiddlefrontal.lh',
    'tfmrinbr2pscdkracgerh': 'tfmri_nback_run2_place_sem_cort.desikan_rostralanteriorcingulate.rh'
}
# We'll need to pull surrounding instances to see what the names should be

# %%
foo = imglbls.reset_index().groupby('other')

# %%
n = 19575
imglbls.loc[n-2:n+2, :]
# Out:
#                                                                   name  \
# 19573            tfmri_nback_run2_place_sem_cort.desikan_precentral.rh
# 19574             tfmri_nback_run2_place_sem_cort.desikan_precuneus.rh
# 19575                                            tfmrinbr2pscdkracgerh
# 19576  tfmri_nback_run2_place_sem_cort.desikan_rostralmiddlefrontal.rh
# 19577       tfmri_nback_run2_place_sem_cort.desikan_superiorfrontal.rh
#
#                                                                                                        doc  \
# 19573                Standard error of the mean for nBack run 2 place condition in APARC ROI rh-precentral
# 19574                 Standard error of the mean for nBack run 2 place condition in APARC ROI rh-precuneus
# 19575  Standard error of the mean for nBack run 2 place condition in APARC ROI rh-rostralanteriorcingulate
# 19576      Standard error of the mean for nBack run 2 place condition in APARC ROI rh-rostralmiddlefrontal
# 19577           Standard error of the mean for nBack run 2 place condition in APARC ROI rh-superiorfrontal
#
#         source_file    dat         atlas                      roi  common  \
# 19573  nbackr2sem01   True  cort.desikan            precentral.rh   False
# 19574  nbackr2sem01   True  cort.desikan             precuneus.rh   False
# 19575  nbackr2sem01  False           NaN                      NaN   False
# 19576  nbackr2sem01   True  cort.desikan  rostralmiddlefrontal.rh   False
# 19577  nbackr2sem01   True  cort.desikan       superiorfrontal.rh   False
#
#                        other
# 19573                    NaN
# 19574                    NaN
# 19575  tfmrinbr2pscdkracgerh
# 19576                    NaN
# 19577                    NaN

# %%
foo.groups
# Out:
# {'465': Int64Index([16857, 18669], dtype='int64'),
#  '473': Int64Index([17771], dtype='int64'),
#  'cdmdftrh': Int64Index([4916], dtype='int64'),
#  'clmdfrh': Int64Index([5931], dtype='int64'),
#  'dof': Int64Index([ 4220,  5234,  6250,  6960,  7670,  8576,  9482, 10498, 11513,
#              12528, 13544, 14254, 14964, 15674, 16384, 17290, 18196, 19102],
#             dtype='int64'),
#  'id': Int64Index([    1,   763,  1221,  1993,  2430,  3346,  4209,  4532,  5224,
#               5547,  6239,  6949,  7659,  8565,  9471,  9794, 10487, 10810,
#              11502, 11825, 12517, 12840, 13533, 14243, 14953, 15663, 16373,
#              17279, 18185, 19091],
#             dtype='int64'),
#  'max.motion': Int64Index([ 4224,  5238,  6254,  6964,  7674,  8580,  9486, 10502, 11517,
#              12532, 13548, 14258, 14968, 15678, 16388, 17294, 18200, 19106],
#             dtype='int64'),
#  'max.rot': Int64Index([ 4228,  5242,  6258,  6968,  7678,  8584,  9490, 10506, 11521,
#              12536, 13552, 14262, 14972, 15682, 16392, 17298, 18204, 19110],
#             dtype='int64'),
#  'max.trans': Int64Index([ 4226,  5240,  6256,  6966,  7676,  8582,  9488, 10504, 11519,
#              12534, 13550, 14260, 14970, 15680, 16390, 17296, 18202, 19108],
#             dtype='int64'),
#  'mean.motion': Int64Index([ 1230,  2439,  4223,  5237,  6253,  6963,  7673,  8579,  9485,
#              10501, 11516, 12531, 13547, 14257, 14967, 15677, 16387, 17293,
#              18199, 19105],
#             dtype='int64'),
#  'mean.rot': Int64Index([ 1232,  2441,  4227,  5241,  6257,  6967,  7677,  8583,  9489,
#              10505, 11520, 12535, 13551, 14261, 14971, 15681, 16391, 17297,
#              18203, 19109],
#             dtype='int64'),
#  'mean.trans': Int64Index([ 1231,  2440,  4225,  5239,  6255,  6965,  7675,  8581,  9487,
#              10503, 11518, 12533, 13549, 14259, 14969, 15679, 16389, 17295,
#              18201, 19107],
#             dtype='int64'),
#  'numtrs': Int64Index([ 4219,  5233,  6249,  6959,  7669,  8575,  9481, 10497, 11512,
#              12527, 13543, 14253, 14963, 15673, 16383, 17289, 18195, 19101],
#             dtype='int64'),
#  'nvols': Int64Index([ 4221,  5235,  6251,  6961,  7671,  8577,  9483, 10499, 11514,
#              12529, 13545, 14255, 14965, 15675, 16385, 17291, 18197, 19103],
#             dtype='int64'),
#  'rncntelh': Int64Index([1942], dtype='int64'),
#  'rrmdfrlh': Int64Index([677], dtype='int64'),
#  'subthresh.nvols': Int64Index([ 4222,  5236,  6252,  6962,  7672,  8578,  9484, 10500, 11515,
#              12530, 13546, 14256, 14966, 15676, 16386, 17292, 18198, 19104],
#             dtype='int64'),
#  'tfmrinbr2pscdkracgerh': Int64Index([19575], dtype='int64'),
#  'tr': Int64Index([ 4218,  5232,  6248,  6958,  7668,  8574,  9480, 10496, 11511,
#              12526, 13542, 14252, 14962, 15672, 16382, 17288, 18194, 19100],
#             dtype='int64'),
#  'visitid': Int64Index([    9,  1229,  2438,  4217,  5231,  6247,  6957,  7667,  8573,
#               9479, 10495, 11510, 12525, 13541, 14251, 14961, 15671, 16381,
#              17287, 18193, 19099],
#             dtype='int64')}

# %%
imglbls[imglbls.doc.str.contains('rostral anterior cingulate')]
# Out:
#                                                           name  \
# 1587   dmri_dti.fa.wm_cort.desikan_rostralanteriorcingulate.lh
# 1621   dmri_dti.fa.wm_cort.desikan_rostralanteriorcingulate.rh
# 1658   dmri_dti.md.wm_cort.desikan_rostralanteriorcingulate.lh
# 1692   dmri_dti.md.wm_cort.desikan_rostralanteriorcingulate.rh
# 1729   dmri_dti.ld.wm_cort.desikan_rostralanteriorcingulate.lh
# 1763   dmri_dti.ld.wm_cort.desikan_rostralanteriorcingulate.rh
# 1800   dmri_dti.td.wm_cort.desikan_rostralanteriorcingulate.lh
# 1834   dmri_dti.td.wm_cort.desikan_rostralanteriorcingulate.rh
# 1871   dmri_dti.fa.gm_cort.desikan_rostralanteriorcingulate.lh
# 1905   dmri_dti.fa.gm_cort.desikan_rostralanteriorcingulate.rh
# 1942                                dmri_dtimdgm_cdsn_rncntelh
# 1976   dmri_dti.md.gm_cort.desikan_rostralanteriorcingulate.rh
# 2024   dmri_dti.ld.gm_cort.desikan_rostralanteriorcingulate.lh
# 2058   dmri_dti.ld.gm_cort.desikan_rostralanteriorcingulate.rh
# 2095   dmri_dti.td.gm_cort.desikan_rostralanteriorcingulate.lh
# 2129   dmri_dti.td.gm_cort.desikan_rostralanteriorcingulate.rh
# 2166  dmri_dti.fa.gwc_cort.desikan_rostralanteriorcingulate.lh
# 2200  dmri_dti.fa.gwc_cort.desikan_rostralanteriorcingulate.rh
# 2237  dmri_dti.md.gwc_cort.desikan_rostralanteriorcingulate.lh
# 2271  dmri_dti.md.gwc_cort.desikan_rostralanteriorcingulate.rh
# 2308  dmri_dti.ld.gwc_cort.desikan_rostralanteriorcingulate.lh
# 2342  dmri_dti.ld.gwc_cort.desikan_rostralanteriorcingulate.rh
# 2379  dmri_dti.td.gwc_cort.desikan_rostralanteriorcingulate.lh
# 2413  dmri_dti.td.gwc_cort.desikan_rostralanteriorcingulate.rh
#
#                                                                                                                                                     doc  \
# 1587              Average fractional anisotropy, parcellation of sub-adjacent white matter associated with cortical ROI left-rostral anterior cingulate
# 1621             Average fractional anisotropy, parcellation of sub-adjacent white matter associated with cortical ROI right-rostral anterior cingulate
# 1658                           Mean diffusivity, parcellation of sub-adjacent white matter associated with cortical ROI left-rostral anterior cingulate
# 1692                          Mean diffusivity, parcellation of sub-adjacent white matter associated with cortical ROI right-rostral anterior cingulate
# 1729           Average longitudinal diffusivity, parcellation of sub-adjacent white matter associated with cortical ROI left-rostral anterior cingulate
# 1763          Average longitudinal diffusivity, parcellation of sub-adjacent white matter associated with cortical ROI right-rostral anterior cingulate
# 1800             Average transverse diffusivity, parcellation of sub-adjacent white matter associated with cortical ROI left-rostral anterior cingulate
# 1834            Average transverse diffusivity, parcellation of sub-adjacent white matter associated with cortical ROI right-rostral anterior cingulate
# 1871              Average fractional anisotropy, parcellation of sub-adjacent white matter associated with cortical ROI left-rostral anterior cingulate
# 1905             Average fractional anisotropy, parcellation of sub-adjacent white matter associated with cortical ROI right-rostral anterior cingulate
# 1942                                Mean diffusivity, parcellation of cortical gray matter associated with cortical ROI left-rostral anterior cingulate
# 1976                               Mean diffusivity, parcellation of cortical gray matter associated with cortical ROI right-rostral anterior cingulate
# 2024                Average longitudinal diffusivity, parcellation of cortical gray matter associated with cortical ROI left-rostral anterior cingulate
# 2058               Average longitudinal diffusivity, parcellation of cortical gray matter associated with cortical ROI right-rostral anterior cingulate
# 2095                  Average transverse diffusivity, parcellation of cortical gray matter associated with cortical ROI left-rostral anterior cingulate
# 2129                 Average transverse diffusivity, parcellation of cortical gray matter associated with cortical ROI right-rostral anterior cingulate
# 2166      Average fractional anisotropy, parcellation of gray matter-white matter contrast associated with cortical ROI left-rostral anterior cingulate
# 2200     Average fractional anisotropy, parcellation of gray matter-white matter contrast associated with cortical ROI right-rostral anterior cingulate
# 2237                   Mean diffusivity, parcellation of gray matter-white matter contrast associated with cortical ROI left-rostral anterior cingulate
# 2271                  Mean diffusivity, parcellation of gray matter-white matter contrast associated with cortical ROI right-rostral anterior cingulate
# 2308   Average longitudinal diffusivity, parcellation of gray matter-white matter contrast associated with cortical ROI left-rostral anterior cingulate
# 2342  Average longitudinal diffusivity, parcellation of gray matter-white matter contrast associated with cortical ROI right-rostral anterior cingulate
# 2379     Average transverse diffusivity, parcellation of gray matter-white matter contrast associated with cortical ROI left-rostral anterior cingulate
# 2413    Average transverse diffusivity, parcellation of gray matter-white matter contrast associated with cortical ROI right-rostral anterior cingulate
#
#         source_file    dat         atlas                          roi  common  \
# 1587  abcd_dti_p101   True  cort.desikan  rostralanteriorcingulate.lh   False
# 1621  abcd_dti_p101   True  cort.desikan  rostralanteriorcingulate.rh   False
# 1658  abcd_dti_p101   True  cort.desikan  rostralanteriorcingulate.lh   False
# 1692  abcd_dti_p101   True  cort.desikan  rostralanteriorcingulate.rh   False
# 1729  abcd_dti_p101   True  cort.desikan  rostralanteriorcingulate.lh   False
# 1763  abcd_dti_p101   True  cort.desikan  rostralanteriorcingulate.rh   False
# 1800  abcd_dti_p101   True  cort.desikan  rostralanteriorcingulate.lh   False
# 1834  abcd_dti_p101   True  cort.desikan  rostralanteriorcingulate.rh   False
# 1871  abcd_dti_p101   True  cort.desikan  rostralanteriorcingulate.lh   False
# 1905  abcd_dti_p101   True  cort.desikan  rostralanteriorcingulate.rh   False
# 1942  abcd_dti_p101  False           NaN                          NaN   False
# 1976  abcd_dti_p101   True  cort.desikan  rostralanteriorcingulate.rh   False
# 2024  abcd_dti_p201   True  cort.desikan  rostralanteriorcingulate.lh   False
# 2058  abcd_dti_p201   True  cort.desikan  rostralanteriorcingulate.rh   False
# 2095  abcd_dti_p201   True  cort.desikan  rostralanteriorcingulate.lh   False
# 2129  abcd_dti_p201   True  cort.desikan  rostralanteriorcingulate.rh   False
# 2166  abcd_dti_p201   True  cort.desikan  rostralanteriorcingulate.lh   False
# 2200  abcd_dti_p201   True  cort.desikan  rostralanteriorcingulate.rh   False
# 2237  abcd_dti_p201   True  cort.desikan  rostralanteriorcingulate.lh   False
# 2271  abcd_dti_p201   True  cort.desikan  rostralanteriorcingulate.rh   False
# 2308  abcd_dti_p201   True  cort.desikan  rostralanteriorcingulate.lh   False
# 2342  abcd_dti_p201   True  cort.desikan  rostralanteriorcingulate.rh   False
# 2379  abcd_dti_p201   True  cort.desikan  rostralanteriorcingulate.lh   False
# 2413  abcd_dti_p201   True  cort.desikan  rostralanteriorcingulate.rh   False
#
#          other
# 1587       NaN
# 1621       NaN
# 1658       NaN
# 1692       NaN
# 1729       NaN
# 1763       NaN
# 1800       NaN
# 1834       NaN
# 1871       NaN
# 1905       NaN
# 1942  rncntelh
# 1976       NaN
# 2024       NaN
# 2058       NaN
# 2095       NaN
# 2129       NaN
# 2166       NaN
# 2200       NaN
# 2237       NaN
# 2271       NaN
# 2308       NaN
# 2342       NaN
# 2379       NaN
# 2413       NaN

# %% [markdown]
# ### apply name cleaning learned above

# %%
name_report = imglbls.loc[imglbls.name.isin(name_reform.keys()), ['name', 'source_file']].copy()

# %%
name_report['fixed_name'] = name_report.name.apply(lambda x: name_reform[x])

# %%
name_report.loc[:, ['source_file', 'name', 'fixed_name']]
# Out:
#             source_file                           name  \
# 677       abcd_smrip101       smri_t1wcnt_cdk_rrmdfrlh
# 1942      abcd_dti_p101     dmri_dtimdgm_cdsn_rncntelh
# 4916   abcd_midr1bwp201  tfmri_mr1_asrvn_bcdk_cdmdftrh
# 5931        midr2bwp201   tfmri_mr2_asrvn_bcdk_clmdfrh
# 16857     nback_bwroi02            tfmri_nback_all_465
# 17771     nbackallsem01           tfmrinbackallsem_473
# 18669      nbackr1sem01          tfmri_nback_r1sem_465
# 19575      nbackr2sem01          tfmrinbr2pscdkracgerh
#
#                                                                                   fixed_name
# 677                                   smri_t1w.contrast_cort.desikan_rostralmiddlefrontal.lh
# 1942                                 dmri_dti.md.gm_cort.desikan_rostralanteriorcingulate.lh
# 4916   tfmri_mid_run1_antic.small.reward.vs.neutral_beta_cort.desikan_caudalmiddlefrontal.rh
# 5931   tfmri_mid_run2_antic.small.reward.vs.neutral_beta_cort.desikan_caudalmiddlefrontal.rh
# 16857                    tfmri_nback_all_place_beta_cort.desikan_rostralanteriorcingulate.rh
# 17771                           tfmri_nback_all_place_sem_cort.desikan_transversetemporal.rh
# 18669                    tfmri_nback_run1_place_sem_cort.desikan_rostralanteriorcingulate.rh
# 19575                    tfmri_nback_run2_place_sem_cort.desikan_rostralanteriorcingulate.rh

# %%
# Just found the mapping file that will have the real fixed names as opposed to my guesses, lets use that instead
abcd_mapping = pd.read_csv('./ABCDstudyNDA/results/ReleaseNotes1.1/19. ABCD_release_1.1_mapping_file.csv')

# %%
# turns out I cot all the names right
name_report.name.apply(lambda x:abcd_mapping.loc[abcd_mapping['ABCD Release 1.1 name'] == x, 'DEAP name'].values[0])==name_report.fixed_name
# Out:
# 677      True
# 1942     True
# 4916     True
# 5931     True
# 16857    True
# 17771    True
# 18669    True
# 19575    True
# dtype: bool

# %%
for i,row in name_report.iterrows():
    imgtbls[row.source_file] = imgtbls[row.source_file].rename(columns={row['name']:row.fixed_name}).copy()

# %%
imglbls.name = imglbls.name.replace(name_reform)

# %% [markdown]
# ### now that names are clean, get metadata again

# %%
for atlas in atlas_guess:
    imglbls.loc[imglbls.name.str.contains(atlas), 'atlas'] = atlas
imglbls['roi'] = imglbls.loc[pd.notnull(imglbls.atlas), :].apply(lambda x: x['name'].split(x.atlas + '_')[-1], axis=1)
imglbls['common']= imglbls.name.isin(common_cols)
imglbls['dat'] = pd.notnull(imglbls.roi)

# %%
imglbls['long_form_name'] = imglbls.loc[imglbls.common, 'name']

# %%
imglbls.head()
# Out:
#                name  \
# 0     collection_id
# 1  abcd_smrip101_id
# 2        dataset_id
# 3        subjectkey
# 4    src_subject_id
#
#                                                              doc  \
# 0                                                  collection_id
# 1                                               abcd_smrip101_id
# 2                                                     dataset_id
# 3  The NDAR Global Unique Identifier (GUID) for research subject
# 4                     Subject ID how it's defined in lab/project
#
#      source_file    dat atlas  roi  common other  long_form_name
# 0  abcd_smrip101  False   NaN  NaN    True   NaN   collection_id
# 1  abcd_smrip101  False   NaN  NaN   False    id             NaN
# 2  abcd_smrip101  False   NaN  NaN    True   NaN      dataset_id
# 3  abcd_smrip101  False   NaN  NaN    True   NaN      subjectkey
# 4  abcd_smrip101  False   NaN  NaN    True   NaN  src_subject_id

# %%
imglbls['meta'] = False
for tm in tbl_meta:
    tm_ind = imglbls.name.str.contains('_' + tm)
    imglbls.loc[tm_ind & ~imglbls.common, 'meta'] = True
    imglbls.loc[tm_ind & ~imglbls.common, 'long_form_name' ] = 'tbl_' + tm

# %%
imglbls.head(100)
# Out:
#                                                    name  \
# 0                                         collection_id
# 1                                      abcd_smrip101_id
# 2                                            dataset_id
# 3                                            subjectkey
# 4                                        src_subject_id
# 5                                        interview_date
# 6                                         interview_age
# 7                                                gender
# 8                                             eventname
# 9                                          smri_visitid
# 10                  smri_thick_cort.desikan_bankssts.lh
# 11   smri_thick_cort.desikan_caudalanteriorcingulate.lh
# 12       smri_thick_cort.desikan_caudalmiddlefrontal.lh
# 13                    smri_thick_cort.desikan_cuneus.lh
# 14                smri_thick_cort.desikan_entorhinal.lh
# 15                  smri_thick_cort.desikan_fusiform.lh
# 16          smri_thick_cort.desikan_inferiorparietal.lh
# 17          smri_thick_cort.desikan_inferiortemporal.lh
# 18          smri_thick_cort.desikan_isthmuscingulate.lh
# 19          smri_thick_cort.desikan_lateraloccipital.lh
# 20      smri_thick_cort.desikan_lateralorbitofrontal.lh
# 21                   smri_thick_cort.desikan_lingual.lh
# 22       smri_thick_cort.desikan_medialorbitofrontal.lh
# 23            smri_thick_cort.desikan_middletemporal.lh
# 24           smri_thick_cort.desikan_parahippocampal.lh
# 25               smri_thick_cort.desikan_paracentral.lh
# 26           smri_thick_cort.desikan_parsopercularis.lh
# 27             smri_thick_cort.desikan_parsorbitalis.lh
# 28          smri_thick_cort.desikan_parstriangularis.lh
# 29             smri_thick_cort.desikan_pericalcarine.lh
# 30               smri_thick_cort.desikan_postcentral.lh
# 31        smri_thick_cort.desikan_posteriorcingulate.lh
# 32                smri_thick_cort.desikan_precentral.lh
# 33                 smri_thick_cort.desikan_precuneus.lh
# 34  smri_thick_cort.desikan_rostralanteriorcingulate.lh
# 35      smri_thick_cort.desikan_rostralmiddlefrontal.lh
# 36           smri_thick_cort.desikan_superiorfrontal.lh
# 37          smri_thick_cort.desikan_superiorparietal.lh
# 38          smri_thick_cort.desikan_superiortemporal.lh
# 39             smri_thick_cort.desikan_supramarginal.lh
# 40               smri_thick_cort.desikan_frontalpole.lh
# 41              smri_thick_cort.desikan_temporalpole.lh
# 42        smri_thick_cort.desikan_transversetemporal.lh
# 43                    smri_thick_cort.desikan_insula.lh
# 44                  smri_thick_cort.desikan_bankssts.rh
# 45   smri_thick_cort.desikan_caudalanteriorcingulate.rh
# 46       smri_thick_cort.desikan_caudalmiddlefrontal.rh
# 47                    smri_thick_cort.desikan_cuneus.rh
# 48                smri_thick_cort.desikan_entorhinal.rh
# 49                  smri_thick_cort.desikan_fusiform.rh
# 50          smri_thick_cort.desikan_inferiorparietal.rh
# 51          smri_thick_cort.desikan_inferiortemporal.rh
# 52          smri_thick_cort.desikan_isthmuscingulate.rh
# 53          smri_thick_cort.desikan_lateraloccipital.rh
# 54      smri_thick_cort.desikan_lateralorbitofrontal.rh
# 55                   smri_thick_cort.desikan_lingual.rh
# 56       smri_thick_cort.desikan_medialorbitofrontal.rh
# 57            smri_thick_cort.desikan_middletemporal.rh
# 58           smri_thick_cort.desikan_parahippocampal.rh
# 59               smri_thick_cort.desikan_paracentral.rh
# 60           smri_thick_cort.desikan_parsopercularis.rh
# 61             smri_thick_cort.desikan_parsorbitalis.rh
# 62          smri_thick_cort.desikan_parstriangularis.rh
# 63             smri_thick_cort.desikan_pericalcarine.rh
# 64               smri_thick_cort.desikan_postcentral.rh
# 65        smri_thick_cort.desikan_posteriorcingulate.rh
# 66                smri_thick_cort.desikan_precentral.rh
# 67                 smri_thick_cort.desikan_precuneus.rh
# 68  smri_thick_cort.desikan_rostralanteriorcingulate.rh
# 69      smri_thick_cort.desikan_rostralmiddlefrontal.rh
# 70           smri_thick_cort.desikan_superiorfrontal.rh
# 71          smri_thick_cort.desikan_superiorparietal.rh
# 72          smri_thick_cort.desikan_superiortemporal.rh
# 73             smri_thick_cort.desikan_supramarginal.rh
# 74               smri_thick_cort.desikan_frontalpole.rh
# 75              smri_thick_cort.desikan_temporalpole.rh
# 76        smri_thick_cort.desikan_transversetemporal.rh
# 77                    smri_thick_cort.desikan_insula.rh
# 78                    smri_thick_cort.fuzzy2_frontal.lh
# 79                  smri_thick_cort.fuzzy2_posterior.lh
# 80                    smri_thick_cort.fuzzy4_frontal.lh
# 81                  smri_thick_cort.fuzzy4_occipital.lh
# 82                   smri_thick_cort.fuzzy4_temporal.lh
# 83                   smri_thick_cort.fuzzy4_parietal.lh
# 84                   smri_thick_cort.fuzzy12_central.lh
# 85                 smri_thick_cort.fuzzy12_occipital.lh
# 86    smri_thick_cort.fuzzy12_posterolateraltemporal.lh
# 87          smri_thick_cort.fuzzy12_superiorparietal.lh
# 88             smri_thick_cort.fuzzy12_orbitofrontal.lh
# 89          smri_thick_cort.fuzzy12_superiortemporal.lh
# 90          smri_thick_cort.fuzzy12_inferiorparietal.lh
# 91        smri_thick_cort.fuzzy12_dorsomedialfrontal.lh
# 92      smri_thick_cort.fuzzy12_anteromedialtemporal.lh
# 93                 smri_thick_cort.fuzzy12_precuneus.lh
# 94    smri_thick_cort.fuzzy12_dorsolateralprefrontal.lh
# 95           smri_thick_cort.fuzzy12_parsopercularis.lh
# 96                    smri_thick_cort.fuzzy2_frontal.rh
# 97                  smri_thick_cort.fuzzy2_posterior.rh
# 98                    smri_thick_cort.fuzzy4_frontal.rh
# 99                  smri_thick_cort.fuzzy4_occipital.rh
#
#                                                                                                            doc  \
# 0                                                                                                collection_id
# 1                                                                                             abcd_smrip101_id
# 2                                                                                                   dataset_id
# 3                                                The NDAR Global Unique Identifier (GUID) for research subject
# 4                                                                   Subject ID how it's defined in lab/project
# 5              Date on which the interview/genetic test/sampling/imaging/biospecimen was completed. MM/DD/YYYY
# 6                                            Age in months at the time of the interview/test/sampling/imaging.
# 7                                                                                           Sex of the subject
# 8                                                              The event name for which the data was collected
# 9                                                                                                   Visit name
# 10                                  Cortical thickness in mm of APARC ROI lh-Banks of Superior Temporal Sulcus
# 11                                            Cortical thickness in mm of APARC ROI lh-caudalanteriorcingulate
# 12                                                Cortical thickness in mm of APARC ROI lh-caudalmiddlefrontal
# 13                                                             Cortical thickness in mm of APARC ROI lh-cuneus
# 14                                                         Cortical thickness in mm of APARC ROI lh-entorhinal
# 15                                                           Cortical thickness in mm of APARC ROI lh-fusiform
# 16                                                   Cortical thickness in mm of APARC ROI lh-inferiorparietal
# 17                                                   Cortical thickness in mm of APARC ROI lh-inferiortemporal
# 18                                                   Cortical thickness in mm of APARC ROI lh-isthmuscingulate
# 19                                                   Cortical thickness in mm of APARC ROI lh-lateraloccipital
# 20                                               Cortical thickness in mm of APARC ROI lh-lateralorbitofrontal
# 21                                                            Cortical thickness in mm of APARC ROI lh-lingual
# 22                                                Cortical thickness in mm of APARC ROI lh-medialorbitofrontal
# 23                                                     Cortical thickness in mm of APARC ROI lh-middletemporal
# 24                                                    Cortical thickness in mm of APARC ROI lh-parahippocampal
# 25                                                        Cortical thickness in mm of APARC ROI lh-paracentral
# 26                                                    Cortical thickness in mm of APARC ROI lh-parsopercularis
# 27                                                      Cortical thickness in mm of APARC ROI lh-parsorbitalis
# 28                                                   Cortical thickness in mm of APARC ROI lh-parstriangularis
# 29                                                      Cortical thickness in mm of APARC ROI lh-pericalcarine
# 30                                                        Cortical thickness in mm of APARC ROI lh-postcentral
# 31                                                 Cortical thickness in mm of APARC ROI lh-posteriorcingulate
# 32                                                         Cortical thickness in mm of APARC ROI lh-precentral
# 33                                                          Cortical thickness in mm of APARC ROI lh-precuneus
# 34                                           Cortical thickness in mm of APARC ROI lh-rostralanteriorcingulate
# 35                                               Cortical thickness in mm of APARC ROI lh-rostralmiddlefrontal
# 36                                                    Cortical thickness in mm of APARC ROI lh-superiorfrontal
# 37                                                   Cortical thickness in mm of APARC ROI lh-superiorparietal
# 38                                                   Cortical thickness in mm of APARC ROI lh-superiortemporal
# 39                                                      Cortical thickness in mm of APARC ROI lh-supramarginal
# 40                                                        Cortical thickness in mm of APARC ROI lh-frontalpole
# 41                                                       Cortical thickness in mm of APARC ROI lh-temporalpole
# 42                                                 Cortical thickness in mm of APARC ROI lh-transversetemporal
# 43                                                             Cortical thickness in mm of APARC ROI lh-insula
# 44                                  Cortical thickness in mm of APARC ROI rh-Banks of Superior Temporal Sulcus
# 45                                            Cortical thickness in mm of APARC ROI rh-caudalanteriorcingulate
# 46                                                Cortical thickness in mm of APARC ROI rh-caudalmiddlefrontal
# 47                                                             Cortical thickness in mm of APARC ROI rh-cuneus
# 48                                                         Cortical thickness in mm of APARC ROI rh-entorhinal
# 49                                                           Cortical thickness in mm of APARC ROI rh-fusiform
# 50                                                   Cortical thickness in mm of APARC ROI rh-inferiorparietal
# 51                                                   Cortical thickness in mm of APARC ROI rh-inferiortemporal
# 52                                                   Cortical thickness in mm of APARC ROI rh-isthmuscingulate
# 53                                                   Cortical thickness in mm of APARC ROI rh-lateraloccipital
# 54                                               Cortical thickness in mm of APARC ROI rh-lateralorbitofrontal
# 55                                                            Cortical thickness in mm of APARC ROI rh-lingual
# 56                                                Cortical thickness in mm of APARC ROI rh-medialorbitofrontal
# 57                                                     Cortical thickness in mm of APARC ROI rh-middletemporal
# 58                                                    Cortical thickness in mm of APARC ROI rh-parahippocampal
# 59                                                        Cortical thickness in mm of APARC ROI rh-paracentral
# 60                                                    Cortical thickness in mm of APARC ROI rh-parsopercularis
# 61                                                      Cortical thickness in mm of APARC ROI rh-parsorbitalis
# 62                                                   Cortical thickness in mm of APARC ROI rh-parstriangularis
# 63                                                      Cortical thickness in mm of APARC ROI rh-pericalcarine
# 64                                                        Cortical thickness in mm of APARC ROI rh-postcentral
# 65                                                 Cortical thickness in mm of APARC ROI rh-posteriorcingulate
# 66                                                         Cortical thickness in mm of APARC ROI rh-precentral
# 67                                                          Cortical thickness in mm of APARC ROI rh-precuneus
# 68                                           Cortical thickness in mm of APARC ROI rh-rostralanteriorcingulate
# 69                                               Cortical thickness in mm of APARC ROI rh-rostralmiddlefrontal
# 70                                                    Cortical thickness in mm of APARC ROI rh-superiorfrontal
# 71                                                   Cortical thickness in mm of APARC ROI rh-superiorparietal
# 72                                                   Cortical thickness in mm of APARC ROI rh-superiortemporal
# 73                                                      Cortical thickness in mm of APARC ROI rh-supramarginal
# 74                                                        Cortical thickness in mm of APARC ROI rh-frontalpole
# 75                                                       Cortical thickness in mm of APARC ROI rh-temporalpole
# 76                                                 Cortical thickness in mm of APARC ROI rh-transversetemporal
# 77                                                             Cortical thickness in mm of APARC ROI rh-insula
# 78                  Weighted average thickness for genetically derived parcellation with 2 clusters-lh-frontal
# 79                Weighted average thickness for genetically derived parcellation with 2 clusters-lh-posterior
# 80                  Weighted average thickness for genetically derived parcellation with 4 clusters-lh-frontal
# 81                Weighted average thickness for genetically derived parcellation with 4 clusters-lh-occipital
# 82                 Weighted average thickness for genetically derived parcellation with 4 clusters-lh-temporal
# 83                 Weighted average thickness for genetically derived parcellation with 4 clusters-lh-parietal
# 84                 Weighted average thickness for genetically derived parcellation with 12 clusters-lh-central
# 85               Weighted average thickness for genetically derived parcellation with 12 clusters-lh-occipital
# 86  Weighted average thickness for genetically derived parcellation with 12 clusters-lh-posterolateraltemporal
# 87        Weighted average thickness for genetically derived parcellation with 12 clusters-lh-superiorparietal
# 88           Weighted average thickness for genetically derived parcellation with 12 clusters-lh-orbitofrontal
# 89        Weighted average thickness for genetically derived parcellation with 12 clusters-lh-superiortemporal
# 90        Weighted average thickness for genetically derived parcellation with 12 clusters-lh-inferiorparietal
# 91      Weighted average thickness for genetically derived parcellation with 12 clusters-lh-dorsomedialfrontal
# 92    Weighted average thickness for genetically derived parcellation with 12 clusters-lh-anteromedialtemporal
# 93               Weighted average thickness for genetically derived parcellation with 12 clusters-lh-precuneus
# 94  Weighted average thickness for genetically derived parcellation with 12 clusters-lh-dorsolateralprefrontal
# 95         Weighted average thickness for genetically derived parcellation with 12 clusters-lh-parsopercularis
# 96                  Weighted average thickness for genetically derived parcellation with 2 clusters-rh-frontal
# 97                Weighted average thickness for genetically derived parcellation with 2 clusters-rh-posterior
# 98                  Weighted average thickness for genetically derived parcellation with 4 clusters-rh-frontal
# 99                Weighted average thickness for genetically derived parcellation with 4 clusters-rh-occipital
#
#       source_file    dat         atlas                          roi  common  \
# 0   abcd_smrip101  False           NaN                          NaN    True
# 1   abcd_smrip101  False           NaN                          NaN   False
# 2   abcd_smrip101  False           NaN                          NaN    True
# 3   abcd_smrip101  False           NaN                          NaN    True
# 4   abcd_smrip101  False           NaN                          NaN    True
# 5   abcd_smrip101  False           NaN                          NaN    True
# 6   abcd_smrip101  False           NaN                          NaN    True
# 7   abcd_smrip101  False           NaN                          NaN    True
# 8   abcd_smrip101  False           NaN                          NaN    True
# 9   abcd_smrip101  False           NaN                          NaN   False
# 10  abcd_smrip101   True  cort.desikan                  bankssts.lh   False
# 11  abcd_smrip101   True  cort.desikan   caudalanteriorcingulate.lh   False
# 12  abcd_smrip101   True  cort.desikan       caudalmiddlefrontal.lh   False
# 13  abcd_smrip101   True  cort.desikan                    cuneus.lh   False
# 14  abcd_smrip101   True  cort.desikan                entorhinal.lh   False
# 15  abcd_smrip101   True  cort.desikan                  fusiform.lh   False
# 16  abcd_smrip101   True  cort.desikan          inferiorparietal.lh   False
# 17  abcd_smrip101   True  cort.desikan          inferiortemporal.lh   False
# 18  abcd_smrip101   True  cort.desikan          isthmuscingulate.lh   False
# 19  abcd_smrip101   True  cort.desikan          lateraloccipital.lh   False
# 20  abcd_smrip101   True  cort.desikan      lateralorbitofrontal.lh   False
# 21  abcd_smrip101   True  cort.desikan                   lingual.lh   False
# 22  abcd_smrip101   True  cort.desikan       medialorbitofrontal.lh   False
# 23  abcd_smrip101   True  cort.desikan            middletemporal.lh   False
# 24  abcd_smrip101   True  cort.desikan           parahippocampal.lh   False
# 25  abcd_smrip101   True  cort.desikan               paracentral.lh   False
# 26  abcd_smrip101   True  cort.desikan           parsopercularis.lh   False
# 27  abcd_smrip101   True  cort.desikan             parsorbitalis.lh   False
# 28  abcd_smrip101   True  cort.desikan          parstriangularis.lh   False
# 29  abcd_smrip101   True  cort.desikan             pericalcarine.lh   False
# 30  abcd_smrip101   True  cort.desikan               postcentral.lh   False
# 31  abcd_smrip101   True  cort.desikan        posteriorcingulate.lh   False
# 32  abcd_smrip101   True  cort.desikan                precentral.lh   False
# 33  abcd_smrip101   True  cort.desikan                 precuneus.lh   False
# 34  abcd_smrip101   True  cort.desikan  rostralanteriorcingulate.lh   False
# 35  abcd_smrip101   True  cort.desikan      rostralmiddlefrontal.lh   False
# 36  abcd_smrip101   True  cort.desikan           superiorfrontal.lh   False
# 37  abcd_smrip101   True  cort.desikan          superiorparietal.lh   False
# 38  abcd_smrip101   True  cort.desikan          superiortemporal.lh   False
# 39  abcd_smrip101   True  cort.desikan             supramarginal.lh   False
# 40  abcd_smrip101   True  cort.desikan               frontalpole.lh   False
# 41  abcd_smrip101   True  cort.desikan              temporalpole.lh   False
# 42  abcd_smrip101   True  cort.desikan        transversetemporal.lh   False
# 43  abcd_smrip101   True  cort.desikan                    insula.lh   False
# 44  abcd_smrip101   True  cort.desikan                  bankssts.rh   False
# 45  abcd_smrip101   True  cort.desikan   caudalanteriorcingulate.rh   False
# 46  abcd_smrip101   True  cort.desikan       caudalmiddlefrontal.rh   False
# 47  abcd_smrip101   True  cort.desikan                    cuneus.rh   False
# 48  abcd_smrip101   True  cort.desikan                entorhinal.rh   False
# 49  abcd_smrip101   True  cort.desikan                  fusiform.rh   False
# 50  abcd_smrip101   True  cort.desikan          inferiorparietal.rh   False
# 51  abcd_smrip101   True  cort.desikan          inferiortemporal.rh   False
# 52  abcd_smrip101   True  cort.desikan          isthmuscingulate.rh   False
# 53  abcd_smrip101   True  cort.desikan          lateraloccipital.rh   False
# 54  abcd_smrip101   True  cort.desikan      lateralorbitofrontal.rh   False
# 55  abcd_smrip101   True  cort.desikan                   lingual.rh   False
# 56  abcd_smrip101   True  cort.desikan       medialorbitofrontal.rh   False
# 57  abcd_smrip101   True  cort.desikan            middletemporal.rh   False
# 58  abcd_smrip101   True  cort.desikan           parahippocampal.rh   False
# 59  abcd_smrip101   True  cort.desikan               paracentral.rh   False
# 60  abcd_smrip101   True  cort.desikan           parsopercularis.rh   False
# 61  abcd_smrip101   True  cort.desikan             parsorbitalis.rh   False
# 62  abcd_smrip101   True  cort.desikan          parstriangularis.rh   False
# 63  abcd_smrip101   True  cort.desikan             pericalcarine.rh   False
# 64  abcd_smrip101   True  cort.desikan               postcentral.rh   False
# 65  abcd_smrip101   True  cort.desikan        posteriorcingulate.rh   False
# 66  abcd_smrip101   True  cort.desikan                precentral.rh   False
# 67  abcd_smrip101   True  cort.desikan                 precuneus.rh   False
# 68  abcd_smrip101   True  cort.desikan  rostralanteriorcingulate.rh   False
# 69  abcd_smrip101   True  cort.desikan      rostralmiddlefrontal.rh   False
# 70  abcd_smrip101   True  cort.desikan           superiorfrontal.rh   False
# 71  abcd_smrip101   True  cort.desikan          superiorparietal.rh   False
# 72  abcd_smrip101   True  cort.desikan          superiortemporal.rh   False
# 73  abcd_smrip101   True  cort.desikan             supramarginal.rh   False
# 74  abcd_smrip101   True  cort.desikan               frontalpole.rh   False
# 75  abcd_smrip101   True  cort.desikan              temporalpole.rh   False
# 76  abcd_smrip101   True  cort.desikan        transversetemporal.rh   False
# 77  abcd_smrip101   True  cort.desikan                    insula.rh   False
# 78  abcd_smrip101   True   cort.fuzzy2                   frontal.lh   False
# 79  abcd_smrip101   True   cort.fuzzy2                 posterior.lh   False
# 80  abcd_smrip101   True   cort.fuzzy4                   frontal.lh   False
# 81  abcd_smrip101   True   cort.fuzzy4                 occipital.lh   False
# 82  abcd_smrip101   True   cort.fuzzy4                  temporal.lh   False
# 83  abcd_smrip101   True   cort.fuzzy4                  parietal.lh   False
# 84  abcd_smrip101   True  cort.fuzzy12                   central.lh   False
# 85  abcd_smrip101   True  cort.fuzzy12                 occipital.lh   False
# 86  abcd_smrip101   True  cort.fuzzy12    posterolateraltemporal.lh   False
# 87  abcd_smrip101   True  cort.fuzzy12          superiorparietal.lh   False
# 88  abcd_smrip101   True  cort.fuzzy12             orbitofrontal.lh   False
# 89  abcd_smrip101   True  cort.fuzzy12          superiortemporal.lh   False
# 90  abcd_smrip101   True  cort.fuzzy12          inferiorparietal.lh   False
# 91  abcd_smrip101   True  cort.fuzzy12        dorsomedialfrontal.lh   False
# 92  abcd_smrip101   True  cort.fuzzy12      anteromedialtemporal.lh   False
# 93  abcd_smrip101   True  cort.fuzzy12                 precuneus.lh   False
# 94  abcd_smrip101   True  cort.fuzzy12    dorsolateralprefrontal.lh   False
# 95  abcd_smrip101   True  cort.fuzzy12           parsopercularis.lh   False
# 96  abcd_smrip101   True   cort.fuzzy2                   frontal.rh   False
# 97  abcd_smrip101   True   cort.fuzzy2                 posterior.rh   False
# 98  abcd_smrip101   True   cort.fuzzy4                   frontal.rh   False
# 99  abcd_smrip101   True   cort.fuzzy4                 occipital.rh   False
#
#       other  long_form_name   meta
# 0       NaN   collection_id  False
# 1        id          tbl_id   True
# 2       NaN      dataset_id  False
# 3       NaN      subjectkey  False
# 4       NaN  src_subject_id  False
# 5       NaN  interview_date  False
# 6       NaN   interview_age  False
# 7       NaN          gender  False
# 8       NaN       eventname  False
# 9   visitid     tbl_visitid   True
# 10      NaN             NaN  False
# 11      NaN             NaN  False
# 12      NaN             NaN  False
# 13      NaN             NaN  False
# 14      NaN             NaN  False
# 15      NaN             NaN  False
# 16      NaN             NaN  False
# 17      NaN             NaN  False
# 18      NaN             NaN  False
# 19      NaN             NaN  False
# 20      NaN             NaN  False
# 21      NaN             NaN  False
# 22      NaN             NaN  False
# 23      NaN             NaN  False
# 24      NaN             NaN  False
# 25      NaN             NaN  False
# 26      NaN             NaN  False
# 27      NaN             NaN  False
# 28      NaN             NaN  False
# 29      NaN             NaN  False
# 30      NaN             NaN  False
# 31      NaN             NaN  False
# 32      NaN             NaN  False
# 33      NaN             NaN  False
# 34      NaN             NaN  False
# 35      NaN             NaN  False
# 36      NaN             NaN  False
# 37      NaN             NaN  False
# 38      NaN             NaN  False
# 39      NaN             NaN  False
# 40      NaN             NaN  False
# 41      NaN             NaN  False
# 42      NaN          tbl_tr   True
# 43      NaN             NaN  False
# 44      NaN             NaN  False
# 45      NaN             NaN  False
# 46      NaN             NaN  False
# 47      NaN             NaN  False
# 48      NaN             NaN  False
# 49      NaN             NaN  False
# 50      NaN             NaN  False
# 51      NaN             NaN  False
# 52      NaN             NaN  False
# 53      NaN             NaN  False
# 54      NaN             NaN  False
# 55      NaN             NaN  False
# 56      NaN             NaN  False
# 57      NaN             NaN  False
# 58      NaN             NaN  False
# 59      NaN             NaN  False
# 60      NaN             NaN  False
# 61      NaN             NaN  False
# 62      NaN             NaN  False
# 63      NaN             NaN  False
# 64      NaN             NaN  False
# 65      NaN             NaN  False
# 66      NaN             NaN  False
# 67      NaN             NaN  False
# 68      NaN             NaN  False
# 69      NaN             NaN  False
# 70      NaN             NaN  False
# 71      NaN             NaN  False
# 72      NaN             NaN  False
# 73      NaN             NaN  False
# 74      NaN             NaN  False
# 75      NaN             NaN  False
# 76      NaN          tbl_tr   True
# 77      NaN             NaN  False
# 78      NaN             NaN  False
# 79      NaN             NaN  False
# 80      NaN             NaN  False
# 81      NaN             NaN  False
# 82      NaN             NaN  False
# 83      NaN             NaN  False
# 84      NaN             NaN  False
# 85      NaN             NaN  False
# 86      NaN             NaN  False
# 87      NaN             NaN  False
# 88      NaN             NaN  False
# 89      NaN             NaN  False
# 90      NaN             NaN  False
# 91      NaN             NaN  False
# 92      NaN             NaN  False
# 93      NaN             NaN  False
# 94      NaN             NaN  False
# 95      NaN             NaN  False
# 96      NaN             NaN  False
# 97      NaN             NaN  False
# 98      NaN             NaN  False
# 99      NaN             NaN  False

# %% [markdown]
# ### Now that we've dealt with the other columns, lets see what we can parse out of the stuff preceeding the atlas

# %%
# Get the modality
# Does the first tag of the dat column only give us the expected modalities
modalities = pd.unique(imglbls.loc[imglbls.dat, :].apply(lambda x: x['name'].split(x.atlas + '_')[0].split('_')[0], axis=1))
assert (modalities == np.array(['smri', 'dmri', 'tfmri'])).all()

# %%
# looks good, we'll assign that and move on
imglbls['modality'] = imglbls.loc[imglbls.dat, :].apply(lambda x: x['name'].split(x.atlas + '_')[0].split('_')[0], axis=1)

# %%
# Make sure that the smri and dmri each have three fields and that the tfmri has 6
assert pd.unique(imglbls.loc[imglbls.modality == 'smri', :].apply(lambda x: len(x['name'].split(x.atlas + '_')[0].split('_')), axis=1))[0] == 3
assert pd.unique(imglbls.loc[imglbls.modality == 'dmri', :].apply(lambda x: len(x['name'].split(x.atlas + '_')[0].split('_')), axis=1))[0] == 3
assert pd.unique(imglbls.loc[imglbls.modality == 'tfmri', :].apply(lambda x: len(x['name'].split(x.atlas + '_')[0].split('_')), axis=1))[0] == 6
# make sure the last field is blank, corresponding to the trailing underscore
assert pd.unique(imglbls.loc[imglbls.dat, :].apply(lambda x: x['name'].split(x.atlas + '_')[0].split('_')[-1], axis=1))[0] == ''

# %%
# smri labels
smri_labels = pd.unique(imglbls.loc[imglbls.modality == 'smri', :].apply(lambda x: x['name'].split(x.atlas + '_')[0].split('_')[1], axis=1))
assert (smri_labels == np.array(['thick', 'sulc', 'area', 'vol', 't1w.white02', 't1w.gray02',
                                't1w.contrast', 't2w.white02', 't2w.gray02', 't2w.contrast', 't1w',
                                't2w'])).all()
imglbls['metric'] = imglbls.loc[imglbls.modality == 'smri', :].apply(lambda x: x['name'].split(x.atlas + '_')[0].split('_')[1], axis=1)

# %%
# dti labels
dti_labels = pd.unique(imglbls.loc[imglbls.modality == 'dmri', :].apply(lambda x: x['name'].split(x.atlas + '_')[0].split('_')[1], axis=1))
assert (dti_labels == np.array(['dti.fa', 'dti.md', 'dti.ld', 'dti.td', 'dti.vol',
       'dti.fa.wm', 'dti.md.wm', 'dti.ld.wm', 'dti.td.wm', 'dti.fa.gm',
       'dti.md.gm', 'dti.ld.gm', 'dti.td.gm', 'dti.fa.gwc', 'dti.md.gwc',
       'dti.ld.gwc', 'dti.td.gwc', 'rsi.n0', 'rsi.n0s2', 'rsi.nd',
       'rsi.nds2', 'rsi.nt', 'rsi.nts2', 'rsi.vol', 'rsi.n0.wm',
       'rsi.n0s2.wm', 'rsi.nd.wm', 'rsi.nds2.wm', 'rsi.nt.wm',
       'rsi.nts2.wm', 'rsi.n0.gm', 'rsi.n0s2.gm', 'rsi.nd.gm',
       'rsi.nds2.gm', 'rsi.nt.gm', 'rsi.nts2.gm', 'rsi.n0.gwc',
       'rsi.n0s2.gwc', 'rsi.nd.gwc', 'rsi.nds2.gwc', 'rsi.nt.gwc',
       'rsi.nts2.gwc'])).all()
imglbls.loc[imglbls.modality == 'dmri', 'metric'] = imglbls.loc[imglbls.modality == 'dmri', :].apply(lambda x: x['name'].split(x.atlas + '_')[0].split('_')[1], axis=1)

# %%
# fmri data has more levels of organization
for ii in range(6):
    print((ii, pd.unique(imglbls.loc[imglbls.modality == 'tfmri', :].apply(lambda x: x['name'].split(x.atlas + '_')[0].split('_')[ii], axis=1))))
# Out:
# (0, array(['tfmri'], dtype=object))
# (1, array(['mid', 'sst', 'nback'], dtype=object))
# (2, array(['run1', 'run2', 'all'], dtype=object))
# (3, array(['antic.reward.vs.neutral', 'antic.loss.vs.neutral',
#        'reward.pos.vs.neg.feedback', 'loss.pos.vs.neg.feedback',
#        'antic.large.reward.vs.neutral', 'antic.small.reward.vs.neutral',
#        'antic.large.vs.small.reward', 'antic.large.loss.vs.neutral',
#        'antic.small.loss.vs.neutral', 'antic.large.vs.small.loss',
#        'correct.go.vs.fixation', 'correct.stop.vs.correct.go',
#        'incorrect.stop.vs.correct.go', 'any.stop.vs.correct.go',
#        'correct.stop.vs.incorrect.stop', 'incorrect.go.vs.correct.go',
#        'incorrect.go.vs.incorrect.stop', '0.back', '2.back', 'place',
#        'emotion', '2.back.vs.0.back', 'face.vs.place',
#        'emotion.vs.neutface', 'negface.vs.neutface',
#        'posface.vs.neutface'], dtype=object))
# (4, array(['beta', 'sem'], dtype=object))
# (5, array([''], dtype=object))

# %%
# for fmri the levels of organization appear to be modality, task, run, contrast, metric
tasks = pd.unique(imglbls.loc[imglbls.modality == 'tfmri', :].apply(lambda x: x['name'].split(x.atlas + '_')[0].split('_')[1], axis=1))
assert (tasks == np.array(['mid', 'sst', 'nback'])).all()
imglbls['task'] = imglbls.loc[imglbls.modality == 'tfmri', :].apply(lambda x: x['name'].split(x.atlas + '_')[0].split('_')[1], axis=1)

runs = pd.unique(imglbls.loc[imglbls.modality == 'tfmri', :].apply(lambda x: x['name'].split(x.atlas + '_')[0].split('_')[2], axis=1))
assert (runs == np.array(['run1', 'run2', 'all'])).all()
imglbls['run'] = imglbls.loc[imglbls.modality == 'tfmri', :].apply(lambda x: x['name'].split(x.atlas + '_')[0].split('_')[2], axis=1)

contrasts = pd.unique(imglbls.loc[imglbls.modality == 'tfmri', :].apply(lambda x: x['name'].split(x.atlas + '_')[0].split('_')[3], axis=1))
assert (contrasts == np.array(['antic.reward.vs.neutral', 'antic.loss.vs.neutral',
       'reward.pos.vs.neg.feedback', 'loss.pos.vs.neg.feedback',
       'antic.large.reward.vs.neutral', 'antic.small.reward.vs.neutral',
       'antic.large.vs.small.reward', 'antic.large.loss.vs.neutral',
       'antic.small.loss.vs.neutral', 'antic.large.vs.small.loss',
       'correct.go.vs.fixation', 'correct.stop.vs.correct.go',
       'incorrect.stop.vs.correct.go', 'any.stop.vs.correct.go',
       'correct.stop.vs.incorrect.stop', 'incorrect.go.vs.correct.go',
       'incorrect.go.vs.incorrect.stop', '0.back', '2.back', 'place',
       'emotion', '2.back.vs.0.back', 'face.vs.place',
       'emotion.vs.neutface', 'negface.vs.neutface',
       'posface.vs.neutface'])).all()
imglbls['contrast'] = imglbls.loc[imglbls.modality == 'tfmri', :].apply(lambda x: x['name'].split(x.atlas + '_')[0].split('_')[3], axis=1)

metrics = pd.unique(imglbls.loc[imglbls.modality == 'tfmri', :].apply(lambda x: x['name'].split(x.atlas + '_')[0].split('_')[4], axis=1))
assert (metrics == np.array(['beta', 'sem'])).all()
imglbls.loc[imglbls.modality == 'tfmri', 'metric'] = imglbls.loc[imglbls.modality == 'tfmri', :].apply(lambda x: x['name'].split(x.atlas + '_')[0].split('_')[4], axis=1)

# %%
# make ssure there aren't any nans on the modality, task, run, contrast, or metric columns for the corresponding tasks
assert imglbls.loc[imglbls.dat, 'modality'].isnull().sum() == 0
assert imglbls.loc[imglbls.dat, 'metric'].isnull().sum() == 0
assert imglbls.loc[imglbls.dat, 'atlas'].isnull().sum() == 0
assert imglbls.loc[imglbls.dat, 'roi'].isnull().sum() == 0
assert imglbls.loc[imglbls.modality == "fmri", 'task'].isnull().sum() == 0
assert imglbls.loc[imglbls.modality == "fmri", 'run'].isnull().sum() == 0
assert imglbls.loc[imglbls.modality == "fmri", 'contrast'].isnull().sum() == 0

# %%
imglbls.groupby('atlas').roi.nunique()
# Out:
# atlas
# cort.desikan    74
# cort.fuzzy12    24
# cort.fuzzy2      4
# cort.fuzzy4      8
# fiber.at        42
# subcort.aseg    46
# Name: roi, dtype: int64

# %%
imglbls.loc[imglbls.dat, 'long_form_name'] = imglbls.loc[imglbls.dat, 'atlas'] + '__' + imglbls.loc[imglbls.dat, 'roi']

# %%
assert imglbls.long_form_name.isnull().sum() == 0

# %% [markdown]
# ## Now that we've got the labels figured out, lets build the long table

# %%
gblist =['modality', 'metric', 'task', 'run', 'contrast']
gb = imglbls.query('dat').groupby(gblist)
for x,df in gb:
    break

# %%
def make_long(modality, labels, tables, new_id_vars=['modality', 'metric']):
    '''
    Parameters
    ----------
    modality: string
        Name of the modality to extract and make long
    labels: DataFrame
        Information about the column names in the existing tables
        and the appropriate names for those columns in the long table
    tables: Dictonary of DataFrames with source file as key
        The tables from which information will be extracted
    new_id_vars: list of strings, default ['modality', 'metric']
        Names of new id variables described in labels that will
        be added to rows of long table
    
    Returns
    -------
    longtbl: DataFrame
        Partially melted dataframe that now has new_id_vars added
    
        '''
    longtbl = []
    gb = labels.query('dat & modality == @modality').groupby(new_id_vars)
    for x, df in gb:
        # For each set of unique new_id_vars, extract the appropriate
        # information from each source table and merge them
        for sfi, sf in enumerate(np.unique(df.source_file.values)):
            # Combine the id columns present for this source file
            # with the value columns present in this group of new_id_vars
            new_cols = pd.concat([labels.query('source_file == @sf & ~dat'),
                                     df.query('source_file == @sf')])
            
            # Extract the mapping from orig column names to long names
            col_map = {nn:lfn for nn,lfn 
                       in new_cols.loc[:, ['name', 'long_form_name']].values}
            
            # Create map between new_id_var names and values
            id_var_map = {gbi:xi for gbi,xi in zip(new_id_vars,x)}
            
            # Pull the columns, rename them, add new_id_vars
            inner_tmp = (tables[sf].loc[:, new_cols.name]
                                   .rename(columns=col_map)
                                   .assign(**id_var_map)
                                   .assign(source_file=sf))
            
            if sfi ==  0:
                tmp_df = inner_tmp
            else:
                # Figure out which columns are present to merge on
                merge_on = set(tmp_df.columns).intersection(inner_tmp.columns)
                # tbl_id and source_file depend on source_file
                # so don't merge on them
                merge_on.discard('tbl_id')
                merge_on.discard('source_file')
                # merge the tables
                tmp_df = tmp_df.merge(inner_tmp,
                                      on=list(merge_on),
                                      how='outer',
                                      suffixes=('', '_y'))
        longtbl.append(tmp_df)
    
    longtbl = pd.concat(longtbl, sort=False, ignore_index=True)
    return longtbl

# %%
longtbls = []
for modality in modalities:
    # Have to separate by modality because pandas
    # drops rows that are nan in one of the group by columns
    if modality == 'tfmri':
        new_id_vars = ['modality', 'metric', 'task', 'run', 'contrast']
    else:
        new_id_vars = ['modality', 'metric']
    
    longtbls.append(make_long(modality, imglbls, imgtbls, new_id_vars))
#longtbl = pd.concat(longtbls, sort=False, ignore_index=True)

# %%
longtbl = pd.concat(longtbls[:2], sort=False, ignore_index=True)

# %%
longtbl = pd.concat([longtbl, longtbls[2]], sort=False, ignore_index=True)

# %% [markdown]
# # Now we'll merge in balancing

# %%
# For right now at least, it appears that interview date has been set to a single one per subject
# That can act as the visit id
assert longtbl[longtbl.tbl_visitid.notnull()].groupby(['subjectkey'])['interview_date'].nunique().max() == 1

# %%
longtbl = longtbl.merge(for_balancing.loc[:,['subjectkey', 'interview_date', 'site_id_l',
       'mri_info_visitid', 'mri_info_manufacturer', 'mri_info_manufacturersmn',
       'mri_info_deviceserialnumber', 'mri_info_magneticfieldstrength',
       'mri_info_softwareversion']], how='left',
          on=['subjectkey','interview_date'], indicator=True)

# %%
assert longtbl.groupby('_merge')['collection_id'].count()['both'] == len(longtbl)
longtbl.drop('_merge', axis=1, inplace=True)

# %% [markdown]
# # Fix event name

# %%
longtbl = longtbl.merge(for_balancing.loc[:,['subjectkey', 'interview_date', 'eventname']], 
                        how='left',
                        on=['subjectkey','interview_date'],
                        indicator=True,
                        suffixes=('', '_mergetmp'))
assert longtbl.groupby('_merge')['collection_id'].count()['both'] == len(longtbl)
longtbl.drop('_merge', axis=1, inplace=True)
longtbl.eventname.fillna(longtbl.eventname_mergetmp, inplace=True)
longtbl.drop('eventname_mergetmp', axis=1, inplace=True)

# %%
longtbl.columns[longtbl.isnull().sum() == longtbl.shape[0]]
# Out:
# Index(['subcort.aseg__lesion.lh', 'subcort.aseg__lesion.rh'], dtype='object')

# %% [markdown]
# # Now merge in qc tables

# %% [markdown]
# ## connectivity

# %%
fsqc, fsqclbl = load_abcd_table(abcd_table_path + 'freesqc01.txt')

# %%
con = con.merge(fsqc.loc[:, ['subjectkey', 'interview_date', 'eventname', 'fsqc_qc']],
                how='left',
                on=['subjectkey','interview_date', 'eventname'],
                indicator=True)
assert con.groupby('_merge')['collection_id'].count()['both'] == len(con)
con.drop('_merge', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-88b233ced9a5> in <module>
# ----> 1 con = con.merge(fsqc.loc[:, ['subjectkey', 'interview_date', 'eventname', 'fsqc_qc']],
#       2                 how='left',
#       3                 on=['subjectkey','interview_date', 'eventname'],
#       4                 indicator=True)
#       5 assert con.groupby('_merge')['collection_id'].count()['both'] == len(con)
#
# NameError: name 'con' is not defined

# %%
con['qc_ok'] = (con['rsfmri_cor_network.gordon_ntpoints'] > 375) & (con.fsqc_qc == 1)

# %% [markdown]
# ## Everything else

# %%
dmriqc, dmriqclbl = load_abcd_table(abcd_table_path + 'dmriqc01.txt')
mriqc, mriqclbl = load_abcd_table(abcd_table_path + 'mriqc02.txt')
mriqc2, mriqclbl = load_abcd_table(abcd_table_path + 'mriqcp202.txt')
midbeh, _ = load_abcd_table(abcd_table_path + 'abcd_mid02.txt')
nbbeh, _ = load_abcd_table(abcd_table_path + 'abcd_mrinback02.txt')
sstbeh, _ = load_abcd_table(abcd_table_path + 'abcd_sst02.txt')
mrfind, _ = load_abcd_table(abcd_table_path + 'abcd_mrfindings01.txt')
# Out:
# /data/nielsond/python/envs/mriqc/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3191: DtypeWarning: Columns (96,97,496,497,523,524,550,551,854,855,881,882) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# /data/nielsond/python/envs/mriqc/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3191: DtypeWarning: Columns (116,117,143,144,339,340,366,367,393,394,736,742,760,776,778,788,790,798,800,802) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):

# %%
longtbl = longtbl.merge(fsqc.loc[:, ['subjectkey', 'interview_date', 'eventname', 'fsqc_qc']],
                how='left',
                on=['subjectkey','interview_date', 'eventname'],
                indicator=True)
assert longtbl.groupby('_merge')['collection_id'].count()['both'] == len(longtbl)
longtbl.drop('_merge', axis=1, inplace=True)

# %%
longtbl = longtbl.merge(dmriqc.loc[:, ['subjectkey', 'interview_date', 'eventname', 'dmri_dti_postqc_qc']],
                how='left',
                on=['subjectkey','interview_date', 'eventname'],
                indicator=True)
assert longtbl.groupby('_merge')['collection_id'].count()['both'] == len(longtbl)
longtbl.drop('_merge', axis=1, inplace=True)

# %%
longtbl = longtbl.merge(mriqc.loc[:, ['subjectkey', 'interview_date', 'eventname', 'iqc_t2_ok_ser', 'iqc_mid_ok_ser']],
                how='left',
                on=['subjectkey','interview_date', 'eventname'],
                indicator=True)
assert longtbl.groupby('_merge')['collection_id'].count()['both'] == len(longtbl)
longtbl.drop('_merge', axis=1, inplace=True)

# %%
longtbl = longtbl.merge(mriqc2.loc[:, ['subjectkey', 'interview_date', 'iqc_sst_ok_ser', 'iqc_nback_ok_ser']],
                how='left',
                on=['subjectkey','interview_date'],
                indicator=True)
assert longtbl.groupby('_merge')['collection_id'].count()['both'] == len(longtbl)
longtbl.drop('_merge', axis=1, inplace=True)

# %%
longtbl = longtbl.merge(midbeh.loc[:, ['subjectkey', 'interview_date', 'eventname', 'tfmri_mid_beh_perform.flag']],
                how='left',
                on=['subjectkey','interview_date', 'eventname'],
                indicator=True)
assert longtbl.groupby('_merge')['collection_id'].count()['both'] == len(longtbl)
longtbl.drop('_merge', axis=1, inplace=True)
longtbl = longtbl.merge(nbbeh.loc[:, ['subjectkey', 'interview_date', 'eventname', 'tfmri_nback_beh_perform.flag']],
                how='left',
                on=['subjectkey','interview_date', 'eventname'],
                indicator=True)
assert longtbl.groupby('_merge')['collection_id'].count()['both'] == len(longtbl)
longtbl.drop('_merge', axis=1, inplace=True)
longtbl = longtbl.merge(sstbeh.loc[:, ['subjectkey', 'interview_date', 'eventname', 'tfmri_sst_beh_perform.flag']],
                how='left',
                on=['subjectkey','interview_date', 'eventname'],
                indicator=True)
assert longtbl.groupby('_merge')['collection_id'].count()['both'] == len(longtbl)
longtbl.drop('_merge', axis=1, inplace=True)

# %%
longtbl = longtbl.merge(imgtbls['midaparc02'].loc[:, ['subjectkey', 'interview_date', 'eventname', 'tfmri_mid_all_beta_dof']],
                how='left',
                on=['subjectkey','interview_date', 'eventname'],
                indicator=True)
assert longtbl.groupby('_merge')['collection_id'].count()['both'] == len(longtbl)
longtbl.drop('_merge', axis=1, inplace=True)
longtbl = longtbl.merge(imgtbls['abcd_midasemp101'].loc[:, ['subjectkey', 'interview_date', 'eventname', 'tfmri_mid_all_sem_dof']],
                how='left',
                on=['subjectkey','interview_date', 'eventname'],
                indicator=True)
assert longtbl.groupby('_merge')['collection_id'].count()['both'] == len(longtbl)
longtbl.drop('_merge', axis=1, inplace=True)


longtbl = longtbl.merge(imgtbls['mrisst02'].loc[:, ['subjectkey', 'interview_date', 'eventname', 'tfmri_sst_all_beta_dof']],
                how='left',
                on=['subjectkey','interview_date', 'eventname'],
                indicator=True)
assert longtbl.groupby('_merge')['collection_id'].count()['both'] == len(longtbl)
longtbl.drop('_merge', axis=1, inplace=True)
longtbl = longtbl.merge(imgtbls['mrisstsem01'].loc[:, ['subjectkey', 'interview_date', 'eventname', 'tfmri_sst_all_sem_dof']],
                how='left',
                on=['subjectkey','interview_date', 'eventname'],
                indicator=True)
assert longtbl.groupby('_merge')['collection_id'].count()['both'] == len(longtbl)
longtbl.drop('_merge', axis=1, inplace=True)


longtbl = longtbl.merge(imgtbls['nback_bwroi02'].loc[:, ['subjectkey', 'interview_date', 'eventname', 'tfmri_nback_all_beta_dof']],
                how='left',
                on=['subjectkey','interview_date', 'eventname'],
                indicator=True)
assert longtbl.groupby('_merge')['collection_id'].count()['both'] == len(longtbl)
longtbl.drop('_merge', axis=1, inplace=True)
longtbl = longtbl.merge(imgtbls['nbackallsem01'].loc[:, ['subjectkey', 'interview_date', 'eventname', 'tfmri_nback_all_sem_dof']],
                how='left',
                on=['subjectkey','interview_date', 'eventname'],
                indicator=True)
assert longtbl.groupby('_merge')['collection_id'].count()['both'] == len(longtbl)
longtbl.drop('_merge', axis=1, inplace=True)

# %%
longtbl = longtbl.merge(mrfind.loc[:, ['subjectkey', 'interview_date', 'eventname', 'mrif_score', 'mrif_hydrocephalus', 'mrif_herniation']],
                how='left',
                on=['subjectkey','interview_date', 'eventname'],
                indicator=True)
assert longtbl.groupby('_merge')['collection_id'].count()['both'] == len(longtbl)
longtbl.drop('_merge', axis=1, inplace=True)

# %%
longtbl['mr_findings_ok'] = (longtbl['mrif_score'] < 3)  & (longtbl['mrif_hydrocephalus'] == 'no') &  (longtbl['mrif_herniation'] == 'no')

# %%
# Default everyting to qc_ok as False
longtbl['qc_ok'] = False

# %%
# QC qualifications for smri

t1_metrics = ['area', 'sulc', 't1w', 't1w.contrast', 't1w.gray02', 't1w.white02', 'thick', 'vol']
t2_metrics = ['t2w', 't2w.contrast', 't2w.gray02', 't2w.white02']


longtbl.loc[((longtbl.modality == 'smri') 
             & (longtbl.metric.isin(t1_metrics))
             & (longtbl.fsqc_qc == 1)), 'qc_ok'] = True


longtbl.loc[((longtbl.modality == 'smri') 
             & (longtbl.metric.isin(t2_metrics))
             & (longtbl.fsqc_qc == 1)
             & (longtbl.iqc_t2_ok_ser > 0)), 'qc_ok'] = True

# %%
# QC qualifications for dmri
# Only data in fsrois depends on a good fs segmentation, but since I aggregated metrics the way I did, this ends up being all metrics
fs_roi_rows = longtbl.loc[longtbl.modality == 'dmri', imglbls.loc[imglbls.atlas != 'fiber.at', 'long_form_name'].unique()].notnull().sum(1) > 0

longtbl.loc[((longtbl.modality == 'dmri') 
             & fs_roi_rows
             & (longtbl.fsqc_qc == 1)
             & (longtbl.dmri_dti_postqc_qc > 0)), 'qc_ok'] = True

# %%
# QC for MID task
longtbl.loc[((longtbl.modality == 'tfmri') 
             & (longtbl.task == 'mid')
             & (longtbl.fsqc_qc == 1)
             & (longtbl.iqc_mid_ok_ser > 0)
             & (longtbl['tfmri_mid_beh_perform.flag'] == 1)
             & (longtbl.tfmri_mid_all_beta_dof > 200)
             & (longtbl.tfmri_mid_all_sem_dof > 200)), 'qc_ok'] = True

# QC for SST
longtbl.loc[((longtbl.modality == 'tfmri') 
             & (longtbl.task == 'sst')
             & (longtbl.fsqc_qc == 1)
             & (longtbl.iqc_sst_ok_ser > 0)
             & (longtbl['tfmri_sst_beh_perform.flag'] == 1)
             & (longtbl.tfmri_sst_all_beta_dof > 200)
             & (longtbl.tfmri_sst_all_sem_dof > 200)), 'qc_ok'] = True

# QC for nBack
longtbl.loc[((longtbl.modality == 'tfmri') 
             & (longtbl.task == 'nback')
             & (longtbl.fsqc_qc == 1)
             & (longtbl.iqc_nback_ok_ser > 0)
             & (longtbl['tfmri_nback_beh_perform.flag'] == 1)
             & (longtbl.tfmri_nback_all_beta_dof > 200)
             & (longtbl.tfmri_nback_all_sem_dof > 200)), 'qc_ok'] = True

# %%
con.to_pickle(data_dir/'con.pkz')
longtbl.to_pickle(data_dir/'long_table.pkz')
